# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12312016Sample.csv")

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate
# 0  750mL               8  12.99  2016-01-01
# 1  750mL               7  10.99  2016-01-01

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
begInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917          838079.59
# 2               52925          840452.20

# %% [markdown]
# # Deliverable 1A

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %% [markdown]
# # Deliverable 1B

# %%
begInv_Brand = begInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()
begInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917          838079.59
# 2               52925          840452.20

# %%
begInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 3545            14499          463823.01
# 1233            12016          432455.84
# 8068            15341          383371.59
# 4261            15499          340823.01
# 3858            13649          327439.51
# 2753             4625          286703.75
# 8082             9287          278517.13
# 8680             7066          275503.34
# 2589             6766          270572.34
# 3876            14829          266773.71

# %% [markdown]
# # Deliverable 2A

# %%
endInv = pd.read_csv("EndInvFINAL12312016.csv")

# %%
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2016-12-31
# 1  750mL       7  36.99  2016-12-31

# %%
endInv = endInv.rename(columns = {'onHand':'01_01_2016_Qty'})
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  01_01_2016_Qty  Price     endDate
# 0  750mL              11  12.99  2016-12-31
# 1  750mL               7  36.99  2016-12-31

# %%
endInv['InvCost01_01_2016'] = endInv['01_01_2016_Qty'] * endInv['Price']
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  01_01_2016_Qty  Price     endDate  InvCost01_01_2016
# 0  750mL              11  12.99  2016-12-31             142.89
# 1  750mL               7  36.99  2016-12-31             258.93

# %%
endInv_Store = endInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
endInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               79827         1206845.93
# 2               56671          850884.06

# %%
endInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 50             260717         4887260.68
# 73             164589         3254662.81
# 67             163765         3076114.82
# 34             145829         3074616.75
# 76             143866         2975945.18
# 69             150848         2968678.82
# 66             144579         2860504.99
# 74             166015         2803645.13
# 38             129397         2463906.85
# 55             125584         2234836.35

# %%
endInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 50             260717         4887260.68
# 73             164589         3254662.81
# 67             163765         3076114.82
# 34             145829         3074616.75
# 76             143866         2975945.18
# 69             150848         2968678.82
# 66             144579         2860504.99
# 74             166015         2803645.13
# 38             129397         2463906.85
# 55             125584         2234836.35

# %% [markdown]
# ## Deliverable 2b

# %%
endInv_Brand = endInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()
endInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               79827         1206845.93
# 2               56671          850884.06

# %%
endInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 1233            15047          526494.53
# 3545            16770          502932.30
# 2753             7849          470861.51
# 8068            15608          366631.92
# 3405            12268          355649.32
# 4261            16769          351981.31
# 2757            11603          336370.97
# 2589             7922          300956.78
# 1376            13180          276648.20
# 2585            10487          272557.13

# %% [markdown]
# ## Deliverable 3

# %%
merge_1 = pd.merge(left=endInv[['InventoryId','01_01_2016_Qty','InvCost01_01_2016']], right=begInv[['InventoryId','01_01_2016_Qty','InvCost01_01_2016']], how='outer', on=['InventoryId'])

# %%
merge_1
# Out:
#                InventoryId  01_01_2016_Qty_x  InvCost01_01_2016_x  \
# 0        1_HARDERSFIELD_58              11.0               142.89
# 1        1_HARDERSFIELD_62               7.0               258.93
# 2        1_HARDERSFIELD_63               7.0               272.93
# 3        1_HARDERSFIELD_72               4.0               139.96
# 4        1_HARDERSFIELD_75               7.0               104.93
# ...                    ...               ...                  ...
# 256037  79_BALLYMENA_36766               NaN                  NaN
# 256038  79_BALLYMENA_41627               NaN                  NaN
# 256039  79_BALLYMENA_43832               NaN                  NaN
# 256040  79_BALLYMENA_43920               NaN                  NaN
# 256041  79_BALLYMENA_44220               NaN                  NaN
#
#         01_01_2016_Qty_y  InvCost01_01_2016_y
# 0                    8.0               103.92
# 1                    6.0               221.94
# ...

# %%
merge_1.fillna(0)
# Out:
#                InventoryId  01_01_2016_Qty_x  InvCost01_01_2016_x  \
# 0        1_HARDERSFIELD_58              11.0               142.89
# 1        1_HARDERSFIELD_62               7.0               258.93
# 2        1_HARDERSFIELD_63               7.0               272.93
# 3        1_HARDERSFIELD_72               4.0               139.96
# 4        1_HARDERSFIELD_75               7.0               104.93
# ...                    ...               ...                  ...
# 256037  79_BALLYMENA_36766               0.0                 0.00
# 256038  79_BALLYMENA_41627               0.0                 0.00
# 256039  79_BALLYMENA_43832               0.0                 0.00
# 256040  79_BALLYMENA_43920               0.0                 0.00
# 256041  79_BALLYMENA_44220               0.0                 0.00
#
#         01_01_2016_Qty_y  InvCost01_01_2016_y
# 0                    8.0               103.92
# 1                    6.0               221.94
# ...

# %%
merge_1.head()
# Out:
#          InventoryId  01_01_2016_Qty_x  InvCost01_01_2016_x  01_01_2016_Qty_y  \
# 0  1_HARDERSFIELD_58              11.0               142.89               8.0
# 1  1_HARDERSFIELD_62               7.0               258.93               6.0
# 2  1_HARDERSFIELD_63               7.0               272.93               3.0
# 3  1_HARDERSFIELD_72               4.0               139.96               6.0
# 4  1_HARDERSFIELD_75               7.0               104.93              18.0
#
#    InvCost01_01_2016_y
# 0               103.92
# 1               221.94
# 2               116.97
# 3               209.94
# 4               269.82

# %%
import sqlite3

# %%
conn = sqlite3.connect

# %% [markdown]
# ## Deliverable 4A

# %%
purchases = pd.read_csv("PurchasesFINAL12-31-16Sample.csv")

# %%
purchases.head()
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0  69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1  34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
# 3      5_SUTTON_3348      5   3348           Bombay Sapphire Gin  1.75L
# 4   30_CULCHETH_4903     30   4903          Bacardi Superior Rum  200mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2015-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 2           388  ATLANTIC IMPORTING COMPANY       8169  2015-12-24
# 3           480  BACARDI USA INC                  8106  2015-12-20
# 4           480  BACARDI USA INC                  8106  2015-12-20
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
purchasesA = purchases[['VendorName', 'Dollars',]].groupby('VendorName').sum()

# %%
purchasesA
# Out:
#                                     Dollars
# VendorName
# AAPER ALCOHOL & CHEMICAL CO          105.07
# ADAMBA IMPORTS INTL INC            30175.00
# ALISA CARR BEVERAGES               16935.18
# ALTAMAR BRANDS LLC                  4388.99
# AMERICAN SPIRITS EXCHANGE            764.52
# ...                                     ...
# WEIN BAUER INC                     15284.53
# WESTERN SPIRITS BEVERAGE CO       151838.07
# WILLIAM GRANT & SONS INC         2501169.32
# WINE GROUP INC                   2214435.68
# ZORVINO VINEYARDS                  37795.32
#
# [126 rows x 1 columns]

# %%
purchasesA.head()
# Out:
#                                   Dollars
# VendorName
# AAPER ALCOHOL & CHEMICAL CO        105.07
# ADAMBA IMPORTS INTL INC          30175.00
# ALISA CARR BEVERAGES             16935.18
# ALTAMAR BRANDS LLC                4388.99
# AMERICAN SPIRITS EXCHANGE          764.52

# %%
purchasesA.sort_values(by='Dollars',ascending=False).head(10)
# Out:
#                                  Dollars
# VendorName
# DIAGEO NORTH AMERICA INC     21315299.75
# MARTIGNETTI COMPANIES        11709222.19
# JIM BEAM BRANDS COMPANY      10232521.65
# PERNOD RICARD USA            10224899.93
# BACARDI USA INC               7420630.63
# CONSTELLATION BRANDS INC      6584032.72
# BROWN-FORMAN CORP             5719375.62
# ULTRA BEVERAGE COMPANY LLP    5545766.29
# E & J GALLO WINERY            5177067.61
# M S WALKER INC                4647908.17

# %% [markdown]
# ## Deliverable 4B

# %%
purchasesB= purchases[['VendorName', 'PurchasePrice',]].groupby('VendorName').sum()

# %%
purchasesB.head()
# Out:
#                                  PurchasePrice
# VendorName
# AAPER ALCOHOL & CHEMICAL CO             105.07
# ADAMBA IMPORTS INTL INC                4052.67
# ALISA CARR BEVERAGES                   3133.98
# ALTAMAR BRANDS LLC                      808.87
# AMERICAN SPIRITS EXCHANGE                46.45

# %% [markdown]
# # Wasn't able to pull in freight so I sorted by vendors who had the largest purchase price.

# %% [markdown]
# ## Deliverable 4C

# %%
largevendors = purchases.groupby(['VendorNumber','VendorName'])[['PurchasePrice','Dollars', 'Quantity']].sum()

# %%
largevendors = largevendors[largevendors['Dollars']>250000]

# %%
largevendors.head()
# Out:
#                                           PurchasePrice     Dollars  Quantity
# VendorNumber VendorName
# 480          BACARDI USA INC                  550546.66  7420630.63    599721
# 516          BANFI PRODUCTS CORP               72892.12   692669.85     96513
# 653          STATE WINE & SPIRITS              52239.68   650999.58     66129
# 660          SAZERAC NORTH AMERICA INC.       177198.16  1500557.20    215164
# 1128         BROWN-FORMAN CORP                458919.02  5719375.62    423866

# %% [markdown]
# ## Deliverable 4D

# %%
largevendorsA = purchases[purchases['PurchasePrice']>100]

# %%
largevendorsB = purchases[purchases['Quantity']<=1000]

# %%
largevendorsA.head()
# Out:
#               InventoryId  Store  Brand                Description   Size  \
# 697     69_MOUNTMEND_2767     69   2767  Johnnie Walker Blue Label  750mL
# 755     29_AYLESBURY_2767     29   2767  Johnnie Walker Blue Label  750mL
# 812    67_EANVERNESS_2767     67   2767  Johnnie Walker Blue Label  750mL
# 1232  1_HARDERSFIELD_2989      1   2989     The Macallan 18 Yr Old  750mL
# 2505     41_LARNWICK_4528     41   4528      Remy Martin XO Cognac  750mL
#
#       VendorNumber                   VendorName  PONumber      PODate  \
# 697           3960  DIAGEO NORTH AMERICA INC         8173  2015-12-24
# 755           3960  DIAGEO NORTH AMERICA INC         8173  2015-12-24
# 812           3960  DIAGEO NORTH AMERICA INC         8173  2015-12-24
# 1232          2561  EDRINGTON AMERICAS               8175  2015-12-24
# 2505          7239  REMY COINTREAU USA INC           8163  2015-12-23
#
#      ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
largevendorsB.head()
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0  69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1  34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
# 3      5_SUTTON_3348      5   3348           Bombay Sapphire Gin  1.75L
# 4   30_CULCHETH_4903     30   4903          Bacardi Superior Rum  200mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2015-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 2           388  ATLANTIC IMPORTING COMPANY       8169  2015-12-24
# 3           480  BACARDI USA INC                  8106  2015-12-20
# 4           480  BACARDI USA INC                  8106  2015-12-20
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
largevendorsA = purchases[purchases[('PurchasePrice')]>100][['Quantity']<=1000]]
# Out:
#   Cell In[41], line 1
#     largevendorsA = purchases[purchases[('PurchasePrice')]>100][['Quantity']<=1000]]
#                                                                                    ^
# SyntaxError: unmatched ']'

# %% [markdown]
# # wasn't able to completely get a match because I wasn't able to pull in the freight data

# %% [markdown]
# ## Deliverable 4E

# %%
perunit = largevendorsA[largevendorsA['PurchasePrice']/'Dollars']

# %% [markdown]
# ## Deliverable 5

# %%
sales = pd.read_csv("SalesFINAL12-31-16Sample.csv")

# %%
sales.head()
# Out:
#             InventoryId  Store  Brand                   Description  \
# 0   1_HARDERSFIELD_1009      1   1009       Rebel Yell Variety Pack
# 1  1_HARDERSFIELD_10238      1  10238   Layer Cake Primitivo Puglia
# 2  1_HARDERSFIELD_10239      1  10239       Cannonball Cab Svgn Cal
# 3  1_HARDERSFIELD_10266      1  10266  Klinker Brick Old Vine Znfdl
# 4   1_HARDERSFIELD_1029      1   1029  Fulton's Harvest Apple Pie L
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  750mL 3 Pk              1         49.99       49.99  2016-01-02   750.0
# 1       750mL              2         31.98       15.99  2016-01-02   750.0
# 2       750mL              1         13.99       13.99  2016-01-02   750.0
# 3       750mL              1         16.99       16.99  2016-01-09   750.0
# 4       750mL              1          9.99        9.99  2016-01-03   750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# ...

# %%
Merge3 = pd.merge(left=sales['SalesDollars'], right=purchases['PurchasePrice'], how='outer', on=['Brand'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1084\322402714.py in ?()
# ----> 1 Merge3 = pd.merge(left=sales['SalesDollars'], right=purchases['PurchasePrice'], how='outer', on=['Brand'])
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
# ...

# %% [markdown]
# # My computer was having trouble recognizing predefined DF's and I ran out of time to completely fix this. I wanted to create an analysis where I could compare sales dollars coming in vs purchase price for vendors. I wanted a single table that would have very important information clearly depicted for quick access.
