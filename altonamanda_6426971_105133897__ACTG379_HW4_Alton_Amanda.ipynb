# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate
# 0  750mL               8  12.99  2016-01-01
# 1  750mL               7  10.99  2016-01-01

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
begInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917         838,079.59
# 2               52925         840,452.20

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %%
endInv = pd.read_csv("EndInvFINAL12-31-16Sample.csv")
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2016-12-31
# 1  750mL       7  36.99  2016-12-31

# %%
endInv = endInv.rename(columns = {'onHand':'12_31_2016_Qty'})
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate
# 0  750mL              11  12.99  2016-12-31
# 1  750mL               7  36.99  2016-12-31

# %%
endInv['InvCost12_31_2016'] = endInv['12_31_2016_Qty'] * endInv['Price']
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate  InvCost12_31_2016
# 0  750mL              11  12.99  2016-12-31             142.89
# 1  750mL               7  36.99  2016-12-31             258.93

# %%
endInv_Store = endInv[['Store','12_31_2016_Qty','InvCost12_31_2016']].groupby('Store').sum()
endInv_Store.head(2)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 1               79827       1,206,845.93
# 2               56671         850,884.06

# %%
endInv_Store.sort_values(by='InvCost12_31_2016',ascending=False).head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 50             260717       4,887,260.68
# 73             164589       3,254,662.81
# 67             163765       3,076,114.82
# 34             145829       3,074,616.75
# 76             143866       2,975,945.18
# 69             150848       2,968,678.82
# 66             144579       2,860,504.99
# 74             166015       2,803,645.13
# 38             129397       2,463,906.85
# 55             125584       2,234,836.35

# %%
endInv_Store.sort_values(by='InvCost12_31_2016').tail(10).sort_values(by='InvCost12_31_2016', ascending = False)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 50             260717       4,887,260.68
# 73             164589       3,254,662.81
# 67             163765       3,076,114.82
# 34             145829       3,074,616.75
# 76             143866       2,975,945.18
# 69             150848       2,968,678.82
# 66             144579       2,860,504.99
# 74             166015       2,803,645.13
# 38             129397       2,463,906.85
# 55             125584       2,234,836.35

# %% [markdown]
# # Deliverable 1A

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})

# %%
begInv['InvCost_01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']

# %%
begInv_Store.sort_values(by= 'InvCost01_01_2016', ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %% [markdown]
# # Delieverable 1B

# %%
begInv_Brand = begInv[['Brand','01_01_2016_Qty','InvCost_01_01_2016']].groupby('Brand').sum()
begInv_Brand.head(10)
# Out:
#        01_01_2016_Qty  InvCost_01_01_2016
# Brand
# 58                281            3,650.19
# 60                288            3,165.12
# 61                 12              167.88
# 62                384           14,204.16
# 63                365           14,231.35
# 72                151            5,283.49
# 75                 18              269.82
# 77               1261           18,902.39
# 79                902           13,520.98
# 82                 24            8,999.76

# %% [markdown]
# # Deliverable 2A

# %%
endInv_Store.sort_values(by= 'InvCost12_31_2016', ascending=False).head(10) 
endInv_Store.sort_values(by='InvCost12_31_2016').tail(10).sort_values(by='InvCost12_31_2016', ascending = False)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 50             260717       4,887,260.68
# 73             164589       3,254,662.81
# 67             163765       3,076,114.82
# 34             145829       3,074,616.75
# 76             143866       2,975,945.18
# 69             150848       2,968,678.82
# 66             144579       2,860,504.99
# 74             166015       2,803,645.13
# 38             129397       2,463,906.85
# 55             125584       2,234,836.35

# %% [markdown]
# # Deliverable 2B

# %%
endInv_Brand = endInv[['Brand','12_31_2016_Qty','InvCost12_31_2016']].groupby('Brand').sum()
endInv_Brand.head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Brand
# 58                385           5,001.15
# 60                146           1,604.54
# 61                 12             167.88
# 62                459          16,978.41
# 63                442          17,233.58
# 72                139           4,863.61
# 75                  7             104.93
# 77               1764          26,442.36
# 79                995          14,915.05
# 86                 18           5,399.82

# %% [markdown]
# # Deliverable 3

# %%
Inv = pd.merge(left =  begInv[['InventoryId', '01_01_2016_Qty','InvCost_01_01_2016']], right = endInv[['InventoryId', '12_31_2016_Qty','InvCost12_31_2016']], how = 'outer', on = ['InventoryId']).fillna(0)
Inv.head()
# Out:
#          InventoryId  01_01_2016_Qty  InvCost_01_01_2016  12_31_2016_Qty  \
# 0  1_HARDERSFIELD_58            8.00              103.92           11.00
# 1  1_HARDERSFIELD_60            7.00               76.93            0.00
# 2  1_HARDERSFIELD_62            6.00              221.94            7.00
# 3  1_HARDERSFIELD_63            3.00              116.97            7.00
# 4  1_HARDERSFIELD_72            6.00              209.94            4.00
#
#    InvCost12_31_2016
# 0             142.89
# 1               0.00
# 2             258.93
# 3             272.93
# 4             139.96

# %%
len(Inv)
# Out:
# 256042

# %% [markdown]
# # Deliverable 4A

# %%
purchases = pd.read_csv("InvoicePurchases12-31-16Sample.csv")

# %%
Topvendors = purchases[['VendorNumber', 'VendorName', 'Dollars']].groupby(['VendorNumber','VendorName']).sum()

# %%
Topvendors.sort_values(by='Dollars', ascending = False).head(10)
# Out:
#                                                Dollars
# VendorNumber VendorName
# 3960         DIAGEO NORTH AMERICA INC    50,959,796.85
# 4425         MARTIGNETTI COMPANIES       27,821,473.91
# 12546        JIM BEAM BRANDS COMPANY     24,203,151.05
# 17035        PERNOD RICARD USA           24,124,091.56
# 480          BACARDI USA INC             17,624,378.72
# 1392         CONSTELLATION BRANDS INC    15,573,917.90
# 1128         BROWN-FORMAN CORP           13,529,433.08
# 9165         ULTRA BEVERAGE COMPANY LLP  13,210,613.93
# 3252         E & J GALLO WINERY          12,289,608.09
# 9552         M S WALKER INC              10,935,817.30

# %% [markdown]
# # Deliverable 4B

# %%
purchases.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47     None
# 1  2015-12-22  2016-02-21        15     140.55     8.57     None
# 2  2015-12-24  2016-02-16         5     106.60     4.61     None
# 3  2015-12-20  2016-02-05     10100 137,483.78 2,935.20     None
# 4  2015-12-24  2016-02-12      1935  15,527.25   429.20     None

# %%
purchases.groupby(['VendorNumber','VendorName'])[['Freight']].sum().sort_values(by='Freight', ascending = False).head(10)
# Out:
#                                             Freight
# VendorNumber VendorName
# 3960         DIAGEO NORTH AMERICA INC    257,032.07
# 4425         MARTIGNETTI COMPANIES       144,719.92
# 12546        JIM BEAM BRANDS COMPANY     123,880.97
# 17035        PERNOD RICARD USA           123,780.22
# 480          BACARDI USA INC              89,286.27
# 1392         CONSTELLATION BRANDS INC     79,528.99
# 1128         BROWN-FORMAN CORP            68,601.68
# 9165         ULTRA BEVERAGE COMPANY LLP   68,054.70
# 3252         E & J GALLO WINERY           61,966.91
# 9552         M S WALKER INC               55,551.82

# %% [markdown]
# # Deliverable 4C

# %%
dfLargeVendors = purchases.groupby(['VendorNumber','VendorName'])[['Freight','Dollars','Quantity']].sum()

# %%
dfLargeVendors = dfLargeVendors[dfLargeVendors['Dollars']>250000]

# %%
dfLargeVendors.head(10)
# Out:
#                                            Freight       Dollars  Quantity
# VendorNumber VendorName
# 480          BACARDI USA INC             89,286.27 17,624,378.72   1427075
# 516          BANFI PRODUCTS CORP          8,510.41  1,628,866.68    228103
# 653          STATE WINE & SPIRITS         8,014.98  1,529,682.04    154092
# 660          SAZERAC NORTH AMERICA INC.  17,932.33  3,537,977.55    503931
# 1128         BROWN-FORMAN CORP           68,601.68 13,529,433.08   1006122
# 1273         CALEDONIA SPIRITS INC        1,319.77    259,604.70      8202
# 1392         CONSTELLATION BRANDS INC    79,528.99 15,573,917.90   2325892
# 1485         CASTLE BRANDS CORP.          8,497.59  1,679,383.91    105220
# 1587         VINEYARD BRANDS INC          6,015.86  1,196,162.81    171919
# 1590         DIAGEO CHATEAU ESTATE WINES  7,259.75  1,365,472.83    187841

# %%
dfLargeVendors['FreightRate(%)'] = (dfLargeVendors['Freight']/dfLargeVendors['Dollars'])*100 
dfLargeVendors['FreightPerUnit'] = (dfLargeVendors['Freight']/dfLargeVendors['Quantity'])

# %%
dfLargeVendors = dfLargeVendors.sort_values(by = 'FreightRate(%)', ascending = False)

# %%
dfLargeVendors.head(10)
# Out:
#                                             Freight       Dollars  Quantity  \
# VendorNumber VendorName
# 9625         WESTERN SPIRITS BEVERAGE CO   1,933.19    361,249.21     56860
# 1590         DIAGEO CHATEAU ESTATE WINES   7,259.75  1,365,472.83    187841
# 9744         FREDERICK WILDMAN & SONS      3,999.93    759,449.24     70932
# 653          STATE WINE & SPIRITS          8,014.98  1,529,682.04    154092
# 17031        FLAG HILL WINERY & VINEYARD   1,573.31    300,403.20     20608
# 516          BANFI PRODUCTS CORP           8,510.41  1,628,866.68    228103
# 4425         MARTIGNETTI COMPANIES       144,719.92 27,821,473.91   2637275
# 8673         STE MICHELLE WINE ESTATES    15,919.70  3,086,650.70    419822
# 9815         WINE GROUP INC               27,100.41  5,258,636.79    888385
# 9165         ULTRA BEVERAGE COMPANY LLP   68,054.70 13,210,613.93   1077527
#
#                                           FreightRate(%)  FreightPerUnit
# VendorNumber VendorName
# 9625         WESTERN SPIRITS BEVERAGE CO            0.54            0.03
# 1590         DIAGEO CHATEAU ESTATE WINES            0.53            0.04
# 9744         FREDERICK WILDMAN & SONS               0.53            0.06
# 653          STATE WINE & SPIRITS                   0.52            0.05
# 17031        FLAG HILL WINERY & VINEYARD            0.52            0.08
# 516          BANFI PRODUCTS CORP                    0.52            0.04
# 4425         MARTIGNETTI COMPANIES                  0.52            0.05
# 8673         STE MICHELLE WINE ESTATES              0.52            0.04
# 9815         WINE GROUP INC                         0.52            0.03
# 9165         ULTRA BEVERAGE COMPANY LLP             0.52            0.06

# %%
LargeVendors.tail()
# Out:
#                                            Freight      Dollars  Quantity  \
# VendorNumber VendorName
# 8352         LUXCO INC                   10,261.60 2,051,436.01    283260
# 3924         HEAVEN HILL DISTILLERIES    14,069.87 2,816,661.94    352348
# 3089         SIDNEY FRANK IMPORTING CO    8,549.55 1,715,908.88    186464
# 9819         TREASURY WINE ESTATES       14,836.57 2,978,686.40    497770
# 6359         OLE SMOKY DISTILLERY LLC     1,922.00   387,622.69    110162
#
#                                           FrieghtRate(%)  FreightPerUnit  \
# VendorNumber VendorName
# 8352         LUXCO INC                              0.50            0.04
# 3924         HEAVEN HILL DISTILLERIES               0.50            0.04
# 3089         SIDNEY FRANK IMPORTING CO              0.50            0.05
# 9819         TREASURY WINE ESTATES                  0.50            0.03
# 6359         OLE SMOKY DISTILLERY LLC               0.50            0.02
#
#                                           FreightRate(%)
# VendorNumber VendorName
# 8352         LUXCO INC                              0.50
# 3924         HEAVEN HILL DISTILLERIES               0.50
# 3089         SIDNEY FRANK IMPORTING CO              0.50
# 9819         TREASURY WINE ESTATES                  0.50
# 6359         OLE SMOKY DISTILLERY LLC               0.50

# %% [markdown]
# # Deliverable 4D

# %%
dfSmallExpensiveInvoices = purchases[purchases['Freight']>100]
dfSmallExpensiveInvoices
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 3              480  BACARDI USA INC              2016-01-12      8106
# 4              516  BANFI PRODUCTS CORP          2016-01-07      8170
# 6             1128  BROWN-FORMAN CORP            2016-01-09      8150
# 9            11567  CAMPARI AMERICA              2016-01-06      8151
# 11            1485  CASTLE BRANDS CORP.          2016-01-08      8152
# ...            ...                          ...         ...       ...
# 5532          9165  ULTRA BEVERAGE COMPANY LLP   2017-01-10     13658
# 5534          1587  VINEYARD BRANDS INC          2017-01-03     13625
# 5539          9625  WESTERN SPIRITS BEVERAGE CO  2017-01-10     13661
# 5540          3664  WILLIAM GRANT & SONS INC     2017-01-02     13643
# 5541          9815  WINE GROUP INC               2017-01-03     13602
#
#           PODate     PayDate  Quantity    Dollars  Freight        Approval
# 3     2015-12-20  2016-02-05     10100 137,483.78 2,935.20            None
# 4     2015-12-24  2016-02-12      1935  15,527.25   429.20            None
# 6     2015-12-23  2016-02-19      4684  65,403.57 1,808.77            None
# 9     2015-12-23  2016-02-20      1321  12,039.71   398.71            None
# 11    2015-12-23  2016-02-19       320   5,420.41   179.26            None
# ...          ...         ...       ...        ...      ...             ...
# 5532  2016-12-23  2017-02-19     38896 502,128.05 2,761.70  Frank Delahunt
# 5534  2016-12-21  2017-02-11      3015  24,370.78   109.67            None
# 5539  2016-12-23  2017-02-18      4617  37,300.48   186.50            None
# 5540  2016-12-22  2017-02-04      9848 202,815.78   932.95            None
# 5541  2016-12-20  2017-02-08     24747 149,007.56   819.54            None
#
# [2057 rows x 10 columns]

# %%
dfSmallExpensiveInvoices = dfSmallExpensiveInvoices[dfSmallExpensiveInvoices['Quantity']<=1000]

# %%
dfSmallExpensiveInvoices.shape
# Out:
# (39, 10)

# %%
dfSmallExpensiveInvoices.sort_values(by='Quantity', ascending = False)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 1323          2561  EDRINGTON AMERICAS           2016-04-07      9495
# 4849          4848  LAIRD & CO                   2016-11-24     12970
# %%
dfSmallExpensiveInvoices_ByVendor.shape
# Out:
# (18, 5)

# %%
dfSmallExpensiveInvoices['FreightRate(%)'] = ((dfSmallExpensiveInvoices['Freight']/dfSmallExpensiveInvoices['Dollars'])*100)
dfSmallExpensiveInvoices['FreightRatePerUnit'] = (dfSmallExpensiveInvoices['Freight']/dfSmallExpensiveInvoices['Quantity'])
# Out:
# C:\Users\altonam\AppData\Local\Temp\ipykernel_4728\2734032285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSmallExpensiveInvoices['FreightRate(%)'] = ((dfSmallExpensiveInvoices['Freight']/dfSmallExpensiveInvoices['Dollars'])*100)
# C:\Users\altonam\AppData\Local\Temp\ipykernel_4728\2734032285.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfSmallExpensiveInvoices['FreightRatePerUnit'] = (dfSmallExpensiveInvoices['Freight']/dfSmallExpensiveInvoices['Quantity'])

# %%
dfSmallExpensiveInvoices.head()
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 11          1485  CASTLE BRANDS CORP.          2016-01-08      8152
# 16          2242  DELICATO VINEYARDS INC       2016-01-06      8139
# 19          2555  DISARONNO INTERNATIONAL LLC  2016-01-11      8192
# 23          2561  EDRINGTON AMERICAS           2016-01-08      8175
# 28          3924  HEAVEN HILL DISTILLERIES     2016-01-08      8155
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval  \
# 11  2015-12-23  2016-02-19       320 5,420.41   179.26     None
# 16  2015-12-22  2016-02-10       808 6,646.46   127.05     None
# 19  2015-12-25  2016-02-17       385 3,506.41   146.86     None
# 23  2015-12-24  2016-02-10       136 5,645.24   218.18     None
# 28  2015-12-23  2016-02-15       818 7,079.02   200.02     None
#
#     FreightRate(%)  FreightRatePerUnit
# 11            3.31                0.56
# 16            1.91                0.16
# 19            4.19                0.38
# 23            3.86                1.60
# 28            2.83                0.24

# %%
dfLargeVendors.head()
# Out:
#                                           Freight      Dollars  Quantity  \
# VendorNumber VendorName
# 9625         WESTERN SPIRITS BEVERAGE CO 1,933.19   361,249.21     56860
# 1590         DIAGEO CHATEAU ESTATE WINES 7,259.75 1,365,472.83    187841
# 9744         FREDERICK WILDMAN & SONS    3,999.93   759,449.24     70932
# 653          STATE WINE & SPIRITS        8,014.98 1,529,682.04    154092
# 17031        FLAG HILL WINERY & VINEYARD 1,573.31   300,403.20     20608
#
#                                           FreightRate(%)  FreightPerUnit
# VendorNumber VendorName
# 9625         WESTERN SPIRITS BEVERAGE CO            0.54            0.03
# 1590         DIAGEO CHATEAU ESTATE WINES            0.53            0.04
# 9744         FREDERICK WILDMAN & SONS               0.53            0.06
# 653          STATE WINE & SPIRITS                   0.52            0.05
# 17031        FLAG HILL WINERY & VINEYARD            0.52            0.08

# %%
pd.DataFrame([['Freight % of $', dfSmallExpensiveInvoices['FreightRate(%)'].mean(), dfLargeVendors['FreightRate(%)'].mean, purchases['FreightRate(%)'],mean()],])

# %% [markdown]
# # Deliverable 5

# %%
dfSalesPrice = pd.read_csv
