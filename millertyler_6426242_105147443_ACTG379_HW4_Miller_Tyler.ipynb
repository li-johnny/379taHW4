# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate
# 0  750mL               8  12.99  2016-01-01
# 1  750mL               7  10.99  2016-01-01

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
begInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917         838,079.59
# 2               52925         840,452.20

# %% [markdown]
# # Deliverable 1A

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %% [markdown]
# # Deliverable 1B

# %%
begInv_Brand = begInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()
begInv_Brand.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 58                281           3,650.19
# 60                288           3,165.12

# %% [markdown]
# # Deliverable 2A

# %%
endInv = pd.read_csv("EndInvFINAL12-31-16Sample.csv")

# %%
endInv = endInv.rename(columns = {'onHand':'End_Qty'})
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  End_Qty  Price     endDate
# 0  750mL       11  12.99  2016-12-31
# 1  750mL        7  36.99  2016-12-31

# %%
endInv['EInvCost2016'] = endInv['End_Qty'] * endInv['Price']
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  End_Qty  Price     endDate  EInvCost2016
# 0  750mL       11  12.99  2016-12-31        142.89
# 1  750mL        7  36.99  2016-12-31        258.93

# %%
endInv_Store = endInv[['Store','End_Qty','EInvCost2016']].groupby('Store').sum()
endInv_Store.head(2)
# Out:
#        End_Qty  EInvCost2016
# Store
# 1        79827  1,206,845.93
# 2        56671    850,884.06

# %%
endInv_Store.sort_values(by='EInvCost2016',ascending=False).head(10)
# Out:
#        End_Qty  EInvCost2016
# Store
# 50      260717  4,887,260.68
# 73      164589  3,254,662.81
# 67      163765  3,076,114.82
# 34      145829  3,074,616.75
# 76      143866  2,975,945.18
# 69      150848  2,968,678.82
# 66      144579  2,860,504.99
# 74      166015  2,803,645.13
# 38      129397  2,463,906.85
# 55      125584  2,234,836.35

# %% [markdown]
# # Deliverable 2B

# %%
endInv_Brand = endInv[['Brand','End_Qty','EInvCost2016']].groupby('Brand').sum()
endInv_Brand.head(2)
# Out:
#        End_Qty  EInvCost2016
# Brand
# 58         385      5,001.15
# 60         146      1,604.54

# %% [markdown]
# # Deliverable 3

# %%
begInv.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93
# 2  750mL               6  36.99  2016-01-01             221.94
# 3  750mL               3  38.99  2016-01-01             116.97
# 4  750mL               6  34.99  2016-01-01             209.94

# %%
endInv.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  End_Qty  Price     endDate  EInvCost2016
# 0  750mL       11  12.99  2016-12-31        142.89
# 1  750mL        7  36.99  2016-12-31        258.93
# 2  750mL        7  38.99  2016-12-31        272.93
# 3  750mL        4  34.99  2016-12-31        139.96
# 4  750mL        7  14.99  2016-12-31        104.93

# %%
Inventory = pd.merge(left=begInv[["InventoryId", "01_01_2016_Qty", "InvCost01_01_2016"]], 
                     right=endInv[["InventoryId", "End_Qty", "EInvCost2016"]], 
                     how="outer", 
                     on=["InventoryId"])
Inventory.head()
# Out:
#          InventoryId  01_01_2016_Qty  InvCost01_01_2016  End_Qty  EInvCost2016
# 0  1_HARDERSFIELD_58            8.00             103.92    11.00        142.89
# 1  1_HARDERSFIELD_60            7.00              76.93      NaN           NaN
# 2  1_HARDERSFIELD_62            6.00             221.94     7.00        258.93
# 3  1_HARDERSFIELD_63            3.00             116.97     7.00        272.93
# 4  1_HARDERSFIELD_72            6.00             209.94     4.00        139.96

# %%
len(Inventory)
# Out:
# 256042

# %% [markdown]
# # Deliverable 4A

# %%
InvoicePurchases = pd.read_csv("InvoicePurchases12-31-16Sample.csv")
InvoicePurchases.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN
# 3  2015-12-20  2016-02-05     10100 137,483.78 2,935.20      NaN
# 4  2015-12-24  2016-02-12      1935  15,527.25   429.20      NaN

# %%
Vendors = InvoicePurchases[['VendorNumber', 'VendorName', 'Dollars']].groupby('VendorNumber').sum()
Vendors.sort_values(by = 'Dollars', ascending = False).head(10)
# Out:
#                                                      VendorName       Dollars
# VendorNumber
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC... 50,959,796.85
# 4425          MARTIGNETTI COMPANIES MARTIGNETTI COMPANIESMAR... 27,861,690.02
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM... 24,203,151.05
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ... 24,124,091.56
# 480           BACARDI USA INC            BACARDI USA INC    ... 17,624,378.72
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND... 15,573,917.90
# 1128          BROWN-FORMAN CORP          BROWN-FORMAN CORP  ... 13,529,433.08
# 9165          ULTRA BEVERAGE COMPANY LLP ULTRA BEVERAGE COMP... 13,210,613.93
# 3252          E & J GALLO WINERY         E & J GALLO WINERY ... 12,289,608.09
# 9552          M S WALKER INC             M S WALKER INC     ... 10,935,817.30

# %% [markdown]
# # Deliverable 4B

# %%
Vendors_Freight = InvoicePurchases[['VendorNumber', 'VendorName', 'Freight']].groupby('VendorNumber').sum()
Vendors_Freight.sort_values(by = 'Freight', ascending = False).head(10)
# Out:
#                                                      VendorName    Freight
# VendorNumber
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC... 257,032.07
# 4425          MARTIGNETTI COMPANIES MARTIGNETTI COMPANIESMAR... 144,929.24
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM... 123,880.97
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ... 123,780.22
# 480           BACARDI USA INC            BACARDI USA INC    ...  89,286.27
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND...  79,528.99
# 1128          BROWN-FORMAN CORP          BROWN-FORMAN CORP  ...  68,601.68
# 9165          ULTRA BEVERAGE COMPANY LLP ULTRA BEVERAGE COMP...  68,054.70
# 3252          E & J GALLO WINERY         E & J GALLO WINERY ...  61,966.91
# 9552          M S WALKER INC             M S WALKER INC     ...  55,551.82

# %% [markdown]
# # Deliverable 4C

# %%
InvoicePurchases.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval  \
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN
# 3  2015-12-20  2016-02-05     10100 137,483.78 2,935.20      NaN
# 4  2015-12-24  2016-02-12      1935  15,527.25   429.20      NaN
#
#    freight_per_$
# 0           0.02
# 1           0.06
# 2           0.04
# 3           0.02
# 4           0.03

# %%
InvoicePurchases['freight_per_$'] = InvoicePurchases['Freight']/ InvoicePurchases['Dollars']
InvoicePurchases.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval  \
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN
# 3  2015-12-20  2016-02-05     10100 137,483.78 2,935.20      NaN
# 4  2015-12-24  2016-02-12      1935  15,527.25   429.20      NaN
#
#    freight_per_$
# 0           0.02
# 1           0.06
# 2           0.04
# 3           0.02
# 4           0.03

# %%
Vendor_250000 = InvoicePurchases[['VendorNumber', 'VendorName', 'Freight', 'Dollars', 'Quantity', 'freight_per_$']].groupby(['VendorNumber', 'VendorName']).sum().sort_values(by='freight_per_$', ascending=False)
Vendor_250000.head()
# Out:
#                                           Freight    Dollars  Quantity  \
# VendorNumber VendorName
# 4848         LAIRD & CO                  1,043.69 203,011.58     21422
# 90058        ZORVINO VINEYARDS             448.68  86,122.71     10550
# 1273         CALEDONIA SPIRITS INC       1,319.77 259,604.70      8202
# 4550         KLIN SPIRITS LLC              531.50 103,484.29      6840
# 7255         PSP WINES                     648.71 128,895.69     16493
#
#                                           freight_per_$
# VendorNumber VendorName
# 4848         LAIRD & CO                            0.39
# 90058        ZORVINO VINEYARDS                     0.38
# 1273         CALEDONIA SPIRITS INC                 0.37
# 4550         KLIN SPIRITS LLC                      0.36
# 7255         PSP WINES                             0.36

# %%
highest = InvoicePurchases.groupby('VendorNumber')['freight_per_$'].mean().nlargest(10)
highest.head()
# Out:
# VendorNumber
# 4848    0.01
# 90058   0.01
# 1273    0.01
# 4550    0.01
# 7255    0.01
# Name: freight_per_$, dtype: float64

# %%
lowest = InvoicePurchases.groupby('VendorNumber')['freight_per_$'].mean().nsmallest(5)
lowest.head()
# Out:
# VendorNumber
# 54      0.00
# 90026   0.00
# 90033   0.00
# 5083    0.00
# 60      0.00
# Name: freight_per_$, dtype: float64

# %% [markdown]
# # Deliverable 4D

# %%
Transactions = InvoicePurchases[(InvoicePurchases['Freight'] > 100) & (InvoicePurchases['Quantity'] <= 1000)]
Transactions.head()
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 11          1485  CASTLE BRANDS CORP.          2016-01-08      8152
# 16          2242  DELICATO VINEYARDS INC       2016-01-06      8139
# 19          2555  DISARONNO INTERNATIONAL LLC  2016-01-11      8192
# 23          2561  EDRINGTON AMERICAS           2016-01-08      8175
# 28          3924  HEAVEN HILL DISTILLERIES     2016-01-08      8155
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval  freight_per_$
# 11  2015-12-23  2016-02-19       320 5,420.41   179.26      NaN           0.03
# 16  2015-12-22  2016-02-10       808 6,646.46   127.05      NaN           0.02
# 19  2015-12-25  2016-02-17       385 3,506.41   146.86      NaN           0.04
# 23  2015-12-24  2016-02-10       136 5,645.24   218.18      NaN           0.04
# 28  2015-12-23  2016-02-15       818 7,079.02   200.02      NaN           0.03

# %% [markdown]
# # Deliverable 4E

# %%
Transactions['Freight_per_$'] = Transactions['Freight'] / Transactions['Dollars']
Transactions.head()
# Out:
# /var/folders/67/bprwkdn516z_14v3wjbb10900000gn/T/ipykernel_20816/3004235857.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Transactions['Freight_per_$'] = Transactions['Freight'] / Transactions['Dollars']
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 11          1485  CASTLE BRANDS CORP.          2016-01-08      8152
# 16          2242  DELICATO VINEYARDS INC       2016-01-06      8139
# 19          2555  DISARONNO INTERNATIONAL LLC  2016-01-11      8192
# 23          2561  EDRINGTON AMERICAS           2016-01-08      8175
# 28          3924  HEAVEN HILL DISTILLERIES     2016-01-08      8155
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval  \
# 11  2015-12-23  2016-02-19       320 5,420.41   179.26      NaN
# 16  2015-12-22  2016-02-10       808 6,646.46   127.05      NaN
# 19  2015-12-25  2016-02-17       385 3,506.41   146.86      NaN
# 23  2015-12-24  2016-02-10       136 5,645.24   218.18      NaN
# 28  2015-12-23  2016-02-15       818 7,079.02   200.02      NaN
#
#     freight_per_$  Freight_per_$
# 11           0.03           0.03
# 16           0.02           0.02
# 19           0.04           0.04
# 23           0.04           0.04
# 28           0.03           0.03

# %%
Transactions['Freight_per_Unit'] = Transactions['Freight'] / Transactions['Quantity']
Transactions.head()
# Out:
# /var/folders/67/bprwkdn516z_14v3wjbb10900000gn/T/ipykernel_20816/2174578748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Transactions['Freight_per_Unit'] = Transactions['Freight'] / Transactions['Quantity']
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 11          1485  CASTLE BRANDS CORP.          2016-01-08      8152
# 16          2242  DELICATO VINEYARDS INC       2016-01-06      8139
# 19          2555  DISARONNO INTERNATIONAL LLC  2016-01-11      8192
# 23          2561  EDRINGTON AMERICAS           2016-01-08      8175
# 28          3924  HEAVEN HILL DISTILLERIES     2016-01-08      8155
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval  \
# 11  2015-12-23  2016-02-19       320 5,420.41   179.26      NaN
# 16  2015-12-22  2016-02-10       808 6,646.46   127.05      NaN
# 19  2015-12-25  2016-02-17       385 3,506.41   146.86      NaN
# 23  2015-12-24  2016-02-10       136 5,645.24   218.18      NaN
# 28  2015-12-23  2016-02-15       818 7,079.02   200.02      NaN
#
#     freight_per_$  Freight_per_$  Freight_per_Unit
# 11           0.03           0.03              0.56
# 16           0.02           0.02              0.16
# 19           0.04           0.04              0.38
# 23           0.04           0.04              1.60
# 28           0.03           0.03              0.24

# %%
Freight_Data = Transactions[['Freight_per_Unit', 'Freight_per_$', 'VendorName']]
Freight_Data.head()
# Out:
#     Freight_per_Unit  Freight_per_$                   VendorName
# 11              0.56           0.03  CASTLE BRANDS CORP.
# 16              0.16           0.02  DELICATO VINEYARDS INC
# 19              0.38           0.04  DISARONNO INTERNATIONAL LLC
# 23              1.60           0.04  EDRINGTON AMERICAS
# 28              0.24           0.03  HEAVEN HILL DISTILLERIES

# %% [markdown]
# # Deliverable 5

# %%
Sales = pd.read_csv("SalesFINAL12-31-16Sample.csv")

# %%
Sales.head()
# Out:
#             InventoryId  Store  Brand                   Description  \
# 0   1_HARDERSFIELD_1009      1   1009       Rebel Yell Variety Pack
# 1  1_HARDERSFIELD_10238      1  10238   Layer Cake Primitivo Puglia
# 2  1_HARDERSFIELD_10239      1  10239       Cannonball Cab Svgn Cal
# 3  1_HARDERSFIELD_10266      1  10266  Klinker Brick Old Vine Znfdl
# 4   1_HARDERSFIELD_1029      1   1029  Fulton's Harvest Apple Pie L
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  750mL 3 Pk              1         49.99       49.99  2016-01-02  750.00
# 1       750mL              2         31.98       15.99  2016-01-02  750.00
# 2       750mL              1         13.99       13.99  2016-01-02  750.00
# 3       750mL              1         16.99       16.99  2016-01-09  750.00
# 4       750mL              1          9.99        9.99  2016-01-03  750.00
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79      8352  LUXCO INC
# 1               2       0.22      4425        MARTIGNETTI COMPANIES
# 2               2       0.11      4425        MARTIGNETTI COMPANIES
# 3               2       0.11      9552  M S WALKER INC
# 4               1       0.79      3924  HEAVEN HILL DISTILLERIES

# %%
Analysis = Sales[['Description', 'SalesPrice', 'SalesDollars']].groupby('Description').sum().sort_values(by='SalesDollars', ascending=False)
Analysis.head()
# Out:
#                          SalesPrice  SalesDollars
# Description
# Jack Daniels No 7 Black  122,386.78    615,149.40
# Grey Goose Vodka         113,719.76    565,305.45
# Tito's Handmade Vodka     99,660.86    564,900.16
# Capt Morgan Spiced Rum    77,164.32    481,469.39
# Absolut 80 Proof          82,254.68    448,035.22
