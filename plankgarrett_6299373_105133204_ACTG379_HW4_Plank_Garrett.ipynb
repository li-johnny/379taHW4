# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("C:/Users/garre/OneDrive/HW4/HW4 Sampled Data/BegInvFINAL12-31-16Sample.csv")

# %%
endInv = pd.read_csv("C:/Users/garre/OneDrive/HW4/HW4 Sampled Data/EndInvFINAL12-31-16Sample.csv")

# %%
##I was having problems with the schools one drive so I did it a different way I hope this doesnt cause to many problems grading sorry if it does I spent hours trying to figure this out and this was the only way

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate
# 0  750mL               8  12.99  2016-01-01
# 1  750mL               7  10.99  2016-01-01

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
begInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917          838079.59
# 2               52925          840452.20

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %%
begInvBrand = begInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()
begInvBrand.head(1)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 58                281            3650.19

# %%
begInvBrand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 3545            14499          463823.01
# 1233            12016          432455.84
# 8068            15341          383371.59
# 4261            15499          340823.01
# 3858            13649          327439.51
# 2753             4625          286703.75
# 8082             9287          278517.13
# 8680             7066          275503.34
# 2589             6766          270572.34
# 3876            14829          266773.71

# %%
##Deliverable 2

# %%
endInv = endInv.rename(columns = {'onHand':'12_31_2016_Qty'})

# %%
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate
# 0  750mL              11  12.99  2016-12-31
# 1  750mL               7  36.99  2016-12-31

# %%
endInv['InvCost12_31_2016'] = endInv['12_31_2016_Qty'] * endInv['Price']

# %%
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate  InvCost12_31_2016
# 0  750mL              11  12.99  2016-12-31             142.89
# 1  750mL               7  36.99  2016-12-31             258.93

# %%
endInvStore = endInv[['Store', '12_31_2016_Qty', 'InvCost12_31_2016']].groupby('Store').sum()

# %%
endInvStore.sort_values(by='InvCost12_31_2016',ascending=False).head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 50             260717         4887260.68
# 73             164589         3254662.81
# 67             163765         3076114.82
# 34             145829         3074616.75
# 76             143866         2975945.18
# 69             150848         2968678.82
# 66             144579         2860504.99
# 74             166015         2803645.13
# 38             129397         2463906.85
# 55             125584         2234836.35

# %%
endInvBrand = endInv[['Brand', '12_31_2016_Qty', 'InvCost12_31_2016']].groupby('Brand').sum()

# %%
endInvBrand.sort_values(by='InvCost12_31_2016',ascending=False).head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Brand
# 1233            15047          526494.53
# 3545            16770          502932.30
# 2753             7849          470861.51
# 8068            15608          366631.92
# 3405            12268          355649.32
# 4261            16769          351981.31
# 2757            11603          336370.97
# 2589             7922          300956.78
# 1376            13180          276648.20
# 2585            10487          272557.13

# %%
##Deliverable 3

# %%
begInv["Beginning Quantity"] = begInv["01_01_2016_Qty"]
endInv["Ending Quantity"] = endInv["12_31_2016_Qty"]

# %%
Del3 = pd.merge(left=begInv, right=endInv, how="inner", on="InventoryId")

# %%
Del3.head(1)
# Out:
#          InventoryId  Store_x        City_x  Brand_x  \
# 0  1_HARDERSFIELD_58        1  HARDERSFIELD       58
#
#                  Description_x Size_x  01_01_2016_Qty  Price_x   startDate  \
# 0  Gekkeikan Black & Gold Sake  750mL               8    12.99  2016-01-01
#
#    InvCost01_01_2016  ...  Store_y        City_y Brand_y  \
# 0             103.92  ...        1  HARDERSFIELD      58
#
#                  Description_y Size_y 12_31_2016_Qty  Price_y     endDate  \
# 0  Gekkeikan Black & Gold Sake  750mL             11    12.99  2016-12-31
#
#   InvCost12_31_2016  Ending Quantity
# 0            142.89               11
#
# [1 rows x 21 columns]

# %%
Del3a = Del3[["InventoryId", "01_01_2016_Qty", "InvCost01_01_2016", "12_31_2016_Qty", "InvCost12_31_2016"]]
Del3a.head()
# Out:
#          InventoryId  01_01_2016_Qty  InvCost01_01_2016  12_31_2016_Qty  \
# 0  1_HARDERSFIELD_58               8             103.92              11
# 1  1_HARDERSFIELD_62               6             221.94               7
# 2  1_HARDERSFIELD_63               3             116.97               7
# 3  1_HARDERSFIELD_72               6             209.94               4
# 4  1_HARDERSFIELD_75              18             269.82               7
#
#    InvCost12_31_2016
# 0             142.89
# 1             258.93
# 2             272.93
# 3             139.96
# 4             104.93

# %%
##Deliverable4

# %%
pur = pd.read_csv("C:/Users/garre/OneDrive/HW4/HW4 Sampled Data/InvoicePurchases12-31-16Sample.csv")

# %%
pur.head(1)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
#
#        PODate     PayDate  Quantity  Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6   214.26     3.47      NaN

# %%
df2016pur = pur[(pur['InvoiceDate']>='2016-01-01') & (pur['InvoiceDate']<='2016-12-31')]

# %%
Del4a = df2016pur[['VendorName', 'VendorNumber', 'Dollars']].groupby('VendorNumber').sum()
Del4a.sort_values(by='Dollars',ascending=False).head(10)
# Out:
#                                                      VendorName      Dollars
# VendorNumber
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC...  49733333.66
# 4425          MARTIGNETTI COMPANIES MARTIGNETTI COMPANIESMAR...  26851015.81
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM...  23539441.79
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ...  23460507.21
# 480           BACARDI USA INC            BACARDI USA INC    ...  16985053.64
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND...  15187741.32
# 1128          BROWN-FORMAN CORP          BROWN-FORMAN CORP  ...  13139921.12
# 9165          ULTRA BEVERAGE COMPANY LLP ULTRA BEVERAGE COMP...  12433070.97
# 3252          E & J GALLO WINERY         E & J GALLO WINERY ...  11858245.15
# 9552          M S WALKER INC             M S WALKER INC     ...  10294481.73

# %%
##Deliverable 4b

# %%
Del4a = df2016pur[['VendorName', 'VendorNumber', 'Freight']].groupby('VendorNumber').sum()
Del4a.sort_values(by='Freight',ascending=False).head(10)
# Out:
#                                                      VendorName    Freight
# VendorNumber
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC...  250899.75
# 4425          MARTIGNETTI COMPANIES MARTIGNETTI COMPANIESMAR...  139976.94
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM...  120230.57
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ...  120130.51
# 480           BACARDI USA INC            BACARDI USA INC    ...   86153.58
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND...   77791.20
# 1128          BROWN-FORMAN CORP          BROWN-FORMAN CORP  ...   66576.22
# 9165          ULTRA BEVERAGE COMPANY LLP ULTRA BEVERAGE COMP...   63888.38
# 3252          E & J GALLO WINERY         E & J GALLO WINERY ...   59594.41
# 9552          M S WALKER INC             M S WALKER INC     ...   52199.20

# %%
##Deliverable4c

# %%
dfLargeVend = df2016pur.groupby(['VendorNumber', 'VendorName'])[['Freight','Dollars','Quantity']].sum()

# %%
dfLargeVend = dfLargeVend[dfLargeVend['Dollars']>=250000]

# %%
dfLargeVend.head()
# Out:
#                                            Freight      Dollars  Quantity
# VendorNumber VendorName
# 480          BACARDI USA INC              86153.58  16985053.64   1365360
# 516          BANFI PRODUCTS CORP           8034.30   1529676.79    213967
# 653          STATE WINE & SPIRITS          7757.25   1481052.81    149590
# 660          SAZERAC NORTH AMERICA INC.   17198.00   3387877.78    481365
# 1128         BROWN-FORMAN CORP            66576.22  13139921.12    973097

# %%
dfLargeVend['FreightRate(%)'] = (dfLargeVend['Freight']/dfLargeVend['Dollars'])*100
dfLargeVend['FreightPerUnit'] = (dfLargeVend['Freight']/dfLargeVend['Quantity'])

# %%
dfLargeVend= dfLargeVend.sort_values(by='FreightRate(%)', ascending = False)

# %%
dfLargeVend.head(10)
# Out:
#                                             Freight      Dollars  Quantity  \
# VendorNumber VendorName
# 9625         WESTERN SPIRITS BEVERAGE CO    1746.69    323948.73     52243
# 1590         DIAGEO CHATEAU ESTATE WINES    7083.48   1331574.55    183317
# 9744         FREDERICK WILDMAN & SONS       3885.16    736944.55     68087
# 17031        FLAG HILL WINERY & VINEYARD    1477.16    281173.13     19188
# 516          BANFI PRODUCTS CORP            8034.30   1529676.79    213967
# 653          STATE WINE & SPIRITS           7757.25   1481052.81    149590
# 4425         MARTIGNETTI COMPANIES        139767.62  26810799.70   2544805
# 8892         TRINCHERO FAMILY ESTATES      11225.72   2175075.75    340040
# 8673         STE MICHELLE WINE ESTATES     15507.50   3007382.16    411345
# 9815         WINE GROUP INC                26280.87   5109629.23    863638
#
#                                           FreightRate(%)  FreightPerUnit
# VendorNumber VendorName
# ...

# %%
dfLargeVend.tail(5)
# Out:
#                                            Freight     Dollars  Quantity  \
# VendorNumber VendorName
# 8352         LUXCO INC                     9785.35  1951124.00    271443
# 3924         HEAVEN HILL DISTILLERIES     13854.16  2773519.92    346500
# 3089         SIDNEY FRANK IMPORTING CO     8258.10  1656429.63    179772
# 9819         TREASURY WINE ESTATES        14470.47  2903971.85    487654
# 6359         OLE SMOKY DISTILLERY LLC      1876.61   377754.50    108698
#
#                                           FreightRate(%)  FreightPerUnit
# VendorNumber VendorName
# 8352         LUXCO INC                          0.501524        0.036049
# 3924         HEAVEN HILL DISTILLERIES           0.499515        0.039983
# 3089         SIDNEY FRANK IMPORTING CO          0.498548        0.045937
# 9819         TREASURY WINE ESTATES              0.498299        0.029674
# 6359         OLE SMOKY DISTILLERY LLC           0.496780        0.017264

# %%
##Deliverable4d

# %%
dfSmallVend = df2016pur[(df2016pur['Freight']>100) & (df2016pur['Quantity']<1000)]
dfSmallVend.head(1)
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 11          1485  CASTLE BRANDS CORP.          2016-01-08      8152
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval
# 11  2015-12-23  2016-02-19       320  5420.41   179.26      NaN

# %%
dfSmallVend = dfSmallVend.groupby(['VendorNumber', 'VendorName'])[['Freight','Dollars','Quantity']].sum()

# %%
dfSmallVend.sort_values(by="Freight", ascending= False).head(10)
# Out:
#                                           Freight    Dollars  Quantity
# VendorNumber VendorName
# 2561         EDRINGTON AMERICAS           2944.67  570627.52     18120
# 8664         STOLI GROUP,(USA) LLC         349.02   14299.98       975
# 7239         REMY COINTREAU USA INC        348.07    7515.38       382
# 653          STATE WINE & SPIRITS          303.70    5544.89       541
# 6785         PALM BAY INTERNATIONAL INC    242.73    5533.18       715
# 10000        MAJESTIC FINE WINES           218.05    7234.88       875
# 3924         HEAVEN HILL DISTILLERIES      200.02    7079.02       818
# 8352         LUXCO INC                     196.61    6139.47       819
# 4692         KOBRAND CORPORATION           185.93    5336.48       427
# 1485         CASTLE BRANDS CORP.           179.26    5420.41       320

# %%
##Deliverable 4e

# %%
dfSmallVend['FreightRate(%)'] = (dfSmallVend['Freight']/dfSmallVend['Dollars'])*100
dfSmallVend['FreightPerUnit'] = (dfSmallVend['Freight']/dfSmallVend['Quantity'])

# %%
dfSmallVend.head(1)
# Out:
#                                       Freight  Dollars  Quantity  \
# VendorNumber VendorName
# 653          STATE WINE & SPIRITS       303.7  5544.89       541
#
#                                       FreightRate(%)  FreightPerUnit
# VendorNumber VendorName
# 653          STATE WINE & SPIRITS           5.477115        0.561368

# %%
pd.DataFrame([['Freight % of $',dfSmallVend['FreightRate(%)'].mean(),dfLargeVend['FreightRate(%)'].mean()],
              ['Freight per Unit',dfSmallVend['FreightPerUnit'].mean(),dfLargeVend['FreightPerUnit'].mean()]],
             columns=['','Small','Large']).set_index('')
# Out:
#                      Small     Large
#
# Freight % of $    2.753072  0.510544
# Freight per Unit  0.336517  0.054424

# %%
##Deliverable 5

# %%
dfsales = pd.read_csv("C:/Users/garre/OneDrive/HW4/HW4 Sampled Data/SalesFINAL12-31-16Sample.csv")

# %%
dfsales.head(3)
# Out:
#             InventoryId  Store  Brand                  Description  \
# 0   1_HARDERSFIELD_1009      1   1009      Rebel Yell Variety Pack
# 1  1_HARDERSFIELD_10238      1  10238  Layer Cake Primitivo Puglia
# 2  1_HARDERSFIELD_10239      1  10239      Cannonball Cab Svgn Cal
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  750mL 3 Pk              1         49.99       49.99  2016-01-02   750.0
# 1       750mL              2         31.98       15.99  2016-01-02   750.0
# 2       750mL              1         13.99       13.99  2016-01-02   750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79      8352  LUXCO INC
# 1               2       0.22      4425        MARTIGNETTI COMPANIES
# 2               2       0.11      4425        MARTIGNETTI COMPANIES

# %%
Tax = dfsales.groupby(['Description'])[['SalesDollars','ExciseTax','SalesQuantity']].sum()

# %%
Tax.sort_values(by="ExciseTax", ascending= False).head()
# Out:
#                          SalesDollars  ExciseTax  SalesQuantity
# Description
# Capt Morgan Spiced Rum      481469.39   34576.51          29161
# Tito's Handmade Vodka       564900.16   30615.91          27150
# Absolut 80 Proof            448035.22   29797.84          24828
# Jack Daniels No 7 Black     615149.40   27538.03          25960
# Ketel One Vodka             405722.83   22366.33          14877

# %%
Tax['Tax Per Sale']=(Tax['ExciseTax']/Tax['SalesQuantity'])

# %%
Tax.sort_values(by="Tax Per Sale", ascending= False).head(20)
# Out:
#                               SalesDollars  ExciseTax  SalesQuantity  \
# Description
# BeatBox Fruit Punch                 779.61     204.75             39
# BeatBox Blue Razzberry Rtd         1319.34     346.50             66
# Eden Rose Cider Keg                 251.49       3.00              1
# Gekkeikan Sake Calif               1138.83      45.90             17
# Chi Chi's Mai Tai                    43.96       7.36              4
# Parrot Bay Pineapple Orange          17.99       1.84              1
# Caribaya Lemonade Punch              10.99       1.84              1
# Hook's Black Spiced Rum              19.99       1.84              1
# Stolichnaya Salted Karamel           29.99       1.84              1
# Chi Chi's Chocolate Malt RTD         21.98       3.68              2
# White Horse Scotch                   27.99       1.84              1
# Bacardi Party Drinks Hurricn         15.99       1.84              1
# ...

# %%
##I created this to show which products have the highest tax per unit associated with them
