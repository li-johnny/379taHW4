# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# ...               ...                ...
# 78              21395          264342.71
# 18              18777          250850.23
# 29              18328          220660.30
# 5               17968          218720.64
# 3                8379          132241.23
#
# [79 rows x 2 columns]

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %% [markdown]
# # Deliverable 1b

# %%
begInv_Brand = begInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()
begInv_Brand.head(2) # only showing that it worked
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 58                281            3650.19
# 60                288            3165.12

# %%
begInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 3545            14499          463823.01
# 1233            12016          432455.84
# 8068            15341          383371.59
# 4261            15499          340823.01
# 3858            13649          327439.51
# 2753             4625          286703.75
# 8082             9287          278517.13
# 8680             7066          275503.34
# 2589             6766          270572.34
# 3876            14829          266773.71

# %% [markdown]
# # Deliverable 2a

# %%
EndInv = pd.read_csv("EndInvFINAL12-31-16Sample.csv")

# %%
EndInv = EndInv.rename(columns = {'onHand':'12_31_2016_Qty'})
EndInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate
# 0  750mL              11  12.99  2016-12-31
# 1  750mL               7  36.99  2016-12-31

# %% [markdown]
# # Deliverabel 2b

# %%
EndInv['InvCost12_31_2016'] = EndInv['12_31_2016_Qty'] * EndInv['Price']
EndInv_Brand = EndInv[['Brand','12_31_2016_Qty','InvCost12_31_2016']].groupby('Brand').sum()
EndInv_Brand.head(2)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Brand
# 58                385            5001.15
# 60                146            1604.54

# %%
EndInv_Brand.sort_values(by='InvCost12_31_2016',ascending=False).head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Brand
# 1233            15047          526494.53
# 3545            16770          502932.30
# 2753             7849          470861.51
# 8068            15608          366631.92
# 3405            12268          355649.32
# 4261            16769          351981.31
# 2757            11603          336370.97
# 2589             7922          300956.78
# 1376            13180          276648.20
# 2585            10487          272557.13

# %% [markdown]
# # Deliverable 3

# %%
begInv.head(1)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92

# %%
D3 = pd.merge(begInv, EndInv,how = 'outer', on = 'InventoryId')

# %%
D3.head(1)
# Out:
#          InventoryId  Store_x        City_x  Brand_x  \
# 0  1_HARDERSFIELD_58      1.0  HARDERSFIELD     58.0
#
#                  Description_x Size_x  01_01_2016_Qty  Price_x   startDate  \
# 0  Gekkeikan Black & Gold Sake  750mL             8.0    12.99  2016-01-01
#
#    InvCost01_01_2016  Store_y        City_y  Brand_y  \
# 0             103.92      1.0  HARDERSFIELD     58.0
#
#                  Description_y Size_y  12_31_2016_Qty  Price_y     endDate  \
# 0  Gekkeikan Black & Gold Sake  750mL            11.0    12.99  2016-12-31
#
#    InvCost12_31_2016
# 0             142.89

# %%
D3 = D3[['InventoryId','01_01_2016_Qty','InvCost01_01_2016','12_31_2016_Qty','InvCost12_31_2016']].groupby('InventoryId').sum()

# %%
D3
# Out:
#                   01_01_2016_Qty  InvCost01_01_2016  12_31_2016_Qty  \
# InventoryId
# 10_HORNSEY_1000              1.0              14.99             0.0
# 10_HORNSEY_1001             11.0              65.89             0.0
# 10_HORNSEY_1003              0.0               0.00            73.0
# 10_HORNSEY_1005             18.0             629.82             0.0
# 10_HORNSEY_10058            52.0             779.48            24.0
# ...                          ...                ...             ...
# 9_BLACKPOOL_9388             7.0             167.93             4.0
# 9_BLACKPOOL_942              0.0               0.00             2.0
# 9_BLACKPOOL_966              8.0             167.92             9.0
# 9_BLACKPOOL_984             23.0             597.77             5.0
# 9_BLACKPOOL_999              0.0               0.00             0.0
#
#                   InvCost12_31_2016
# InventoryId
# 10_HORNSEY_1000                0.00
# 10_HORNSEY_1001                0.00
# 10_HORNSEY_1003             1678.27
# 10_HORNSEY_1005                0.00
# 10_HORNSEY_10058             359.76
# ...                             ...
# 9_BLACKPOOL_9388              95.96
# 9_BLACKPOOL_942              123.98
# 9_BLACKPOOL_966              188.91
# 9_BLACKPOOL_984              129.95
# 9_BLACKPOOL_999                0.00
#
# [256042 rows x 4 columns]

# %% [markdown]
# # Deliverable 4a

# %%
purchases = pd.read_csv("InvoicePurchases12-31-16Sample.csv")

# %%
purchases = purchases.rename(columns = {'Dollars':'InvCost'})
purchases['TotalCost'] = purchases['InvCost'] + purchases['Freight']

# %%
purchases.head(2)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
#
#        PODate     PayDate  Quantity  InvCost  Freight Approval  TotalCost
# 0  2015-12-21  2016-02-16         6   214.26     3.47      NaN     217.73
# 1  2015-12-22  2016-02-21        15   140.55     8.57      NaN     149.12

# %%
purchasesv = purchases[['VendorNumber','VendorName','TotalCost']].groupby('VendorName').sum()

# %%
purchasesv.sort_values(by='TotalCost',ascending=False).head(10)
# Out:
#                              VendorNumber    TotalCost
# VendorName
# DIAGEO NORTH AMERICA INC           217800  51216828.92
# MARTIGNETTI COMPANIES              243375  27966193.83
# JIM BEAM BRANDS COMPANY            690030  24327032.02
# PERNOD RICARD USA                  936925  24247871.78
# BACARDI USA INC                     26400  17713664.99
# CONSTELLATION BRANDS INC            76560  15653446.89
# BROWN-FORMAN CORP                   62040  13598034.76
# ULTRA BEVERAGE COMPANY LLP         504075  13278668.63
# E & J GALLO WINERY                 178860  12351575.00
# M S WALKER INC                     525360  10991369.12

# %% [markdown]
# # Deliverable 4b

# %%
purchases4b = purchases[['VendorName','Freight']].groupby('VendorName').sum()

# %%
purchases4b.sort_values(by='Freight',ascending=False).head(10)
# Out:
#                                Freight
# VendorName
# DIAGEO NORTH AMERICA INC     257032.07
# MARTIGNETTI COMPANIES        144719.92
# JIM BEAM BRANDS COMPANY      123880.97
# PERNOD RICARD USA            123780.22
# BACARDI USA INC               89286.27
# CONSTELLATION BRANDS INC      79528.99
# BROWN-FORMAN CORP             68601.68
# ULTRA BEVERAGE COMPANY LLP    68054.70
# E & J GALLO WINERY            61966.91
# M S WALKER INC                55551.82

# %% [markdown]
# # Deliverable 4c

# %%
purchases4c = pd.merge(purchasesv,purchases4b,how = 'outer', on = 'VendorName')

# %%
purchases4c['FreightPerDollar'] = purchases4c['Freight']/purchases4c['TotalCost']

# %%
purchases4c.head()
# Out:
#                                  VendorNumber  TotalCost  Freight  \
# VendorName
# AAPER ALCOHOL & CHEMICAL CO                54     105.55     0.48
# ADAMBA IMPORTS INTL INC                  2100   77137.77   367.52
# ALISA CARR BEVERAGES                    32357   35123.68   172.00
# ALTAMAR BRANDS LLC                       4200   11768.59    62.39
# AMERICAN SPIRITS EXCHANGE                1200    1211.35     6.19
#
#                                  FreightPerDollar
# VendorName
# AAPER ALCOHOL & CHEMICAL CO              0.004548
# ADAMBA IMPORTS INTL INC                  0.004764
# ALISA CARR BEVERAGES                     0.004897
# ALTAMAR BRANDS LLC                       0.005301
# AMERICAN SPIRITS EXCHANGE                0.005110

# %%
purchases4cc = purchases4c[purchases4c['TotalCost'] > 250000]

# %%
purchases4cc.sort_values(by='FreightPerDollar',ascending=False).head(10)
# Out:
#                              VendorNumber    TotalCost    Freight  \
# VendorName
# WESTERN SPIRITS BEVERAGE CO        529375    363182.40    1933.19
# DIAGEO CHATEAU ESTATE WINES         87450   1372732.58    7259.75
# FREDERICK WILDMAN & SONS           535920    763449.17    3999.93
# STATE WINE & SPIRITS                35915   1537697.02    8014.98
# FLAG HILL WINERY & VINEYARD        936705    301976.51    1573.31
# BANFI PRODUCTS CORP                 28380   1637377.09    8510.41
# MARTIGNETTI COMPANIES              243375  27966193.83  144719.92
# STE MICHELLE WINE ESTATES          477015   3102570.40   15919.70
# WINE GROUP INC                     539825   5285737.20   27100.41
# ULTRA BEVERAGE COMPANY LLP         504075  13278668.63   68054.70
#
#                              FreightPerDollar
# VendorName
# WESTERN SPIRITS BEVERAGE CO          0.005323
# DIAGEO CHATEAU ESTATE WINES          0.005289
# FREDERICK WILDMAN & SONS             0.005239
# STATE WINE & SPIRITS                 0.005212
# FLAG HILL WINERY & VINEYARD          0.005210
# BANFI PRODUCTS CORP                  0.005198
# MARTIGNETTI COMPANIES                0.005175
# STE MICHELLE WINE ESTATES            0.005131
# WINE GROUP INC                       0.005127
# ULTRA BEVERAGE COMPANY LLP           0.005125

# %%
purchases4cc.sort_values(by='FreightPerDollar',ascending=False).tail(5)
# Out:
#                              VendorNumber   TotalCost   Freight  \
# VendorName
# LUXCO INC                          459360  2061697.61  10261.60
# HEAVEN HILL DISTILLERIES           215820  2830731.81  14069.87
# SIDNEY FRANK IMPORTING CO          169895  1724458.43   8549.55
# TREASURY WINE ESTATES              540045  2993522.97  14836.57
# OLE SMOKY DISTILLERY LLC           343386   389544.69   1922.00
#
#                              FreightPerDollar
# VendorName
# LUXCO INC                            0.004977
# HEAVEN HILL DISTILLERIES             0.004970
# SIDNEY FRANK IMPORTING CO            0.004958
# TREASURY WINE ESTATES                0.004956
# OLE SMOKY DISTILLERY LLC             0.004934

# %% [markdown]
# # Deliverable 4d

# %%
purchases4d = purchases[['Quantity','Freight','VendorName','TotalCost']]

# %%
purchases4d.head()
# Out:
#    Quantity  Freight                   VendorName  TotalCost
# 0         6     3.47  ALTAMAR BRANDS LLC              217.73
# 1        15     8.57  AMERICAN VINTAGE BEVERAGE       149.12
# 2         5     4.61  ATLANTIC IMPORTING COMPANY      111.21
# 3     10100  2935.20  BACARDI USA INC              140418.98
# 4      1935   429.20  BANFI PRODUCTS CORP           15956.45

# %%
purchases4d = purchases4d[(purchases4d['Quantity'] <= 1000) & (purchases4d['Freight'] > 100)]

# %%
purchases4d.head()
# Out:
#     Quantity  Freight                   VendorName  TotalCost
# 11       320   179.26  CASTLE BRANDS CORP.            5599.67
# 16       808   127.05  DELICATO VINEYARDS INC         6773.51
# 19       385   146.86  DISARONNO INTERNATIONAL LLC    3653.27
# 23       136   218.18  EDRINGTON AMERICAS             5863.42
# 28       818   200.02  HEAVEN HILL DISTILLERIES       7279.04

# %%
purchases4d.sort_values(by='Freight',ascending=False).head(10)
# Out:
#      Quantity  Freight                   VendorName  TotalCost
# 71        975   349.02  STOLI GROUP,(USA) LLC         14649.00
# 59        382   348.07  REMY COINTREAU USA INC         7863.45
# 69        541   303.70      STATE WINE & SPIRITS       5848.59
# 50        715   242.73  PALM BAY INTERNATIONAL INC     5775.91
# 407       765   219.65  EDRINGTON AMERICAS            42459.11
# 23        136   218.18  EDRINGTON AMERICAS             5863.42
# 40        875   218.05  MAJESTIC FINE WINES            7452.93
# 28        818   200.02  HEAVEN HILL DISTILLERIES       7279.04
# 38        819   196.61  LUXCO INC                      6336.08
# 34        427   185.93  KOBRAND CORPORATION            5522.41

# %% [markdown]
# # Deliverable 4e

# %%
purchases4d['FreightPerDollar'] = purchases4d['Freight']/purchases4d['TotalCost']

# %%
purchases4d['FreightPerUnit'] = purchases4d['Freight']/purchases4d['Quantity']

# %%
purchases4d.sort_values(by='FreightPerDollar',ascending=False).head(10)
# Out:
#     Quantity  Freight                   VendorName  TotalCost  \
# 69       541   303.70      STATE WINE & SPIRITS       5848.59
# 59       382   348.07  REMY COINTREAU USA INC         7863.45
# 50       715   242.73  PALM BAY INTERNATIONAL INC     5775.91
# 19       385   146.86  DISARONNO INTERNATIONAL LLC    3653.27
# 23       136   218.18  EDRINGTON AMERICAS             5863.42
# 45       412   177.50  MHW LTD                        4999.33
# 34       427   185.93  KOBRAND CORPORATION            5522.41
# 11       320   179.26  CASTLE BRANDS CORP.            5599.67
# 38       819   196.61  LUXCO INC                      6336.08
# 40       875   218.05  MAJESTIC FINE WINES            7452.93
#
#     FreightPerDollar  FreightPerUnit
# 69          0.051927        0.561368
# 59          0.044264        0.911178
# 50          0.042025        0.339483
# 19          0.040200        0.381455
# 23          0.037210        1.604265
# 45          0.035505        0.430825
# 34          0.033668        0.435433
# 11          0.032013        0.560187
# 38          0.031030        0.240061
# 40          0.029257        0.249200

# %% [markdown]
# When compared to the answer in 4c, the freight per dollar is much higher

# %% [markdown]
# # Deliverable 5

# %%
sales = pd.read_csv("salesFINAL12-31-16Sample.csv")

# %%
sales.head(2)
# Out:
#             InventoryId  Store  Brand                  Description  \
# 0   1_HARDERSFIELD_1009      1   1009      Rebel Yell Variety Pack
# 1  1_HARDERSFIELD_10238      1  10238  Layer Cake Primitivo Puglia
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  750mL 3 Pk              1         49.99       49.99  2016-01-02   750.0
# 1       750mL              2         31.98       15.99  2016-01-02   750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79      8352  LUXCO INC
# 1               2       0.22      4425        MARTIGNETTI COMPANIES

# %%
sales = sales[['VendorName','InventoryId','Description','SalesQuantity','SalesDollars',]]

# %%
sales['TotalSale'] = sales['SalesQuantity']*sales['SalesDollars']

# %%
sales.head()
# Out:
#                     VendorName           InventoryId  \
# 0  LUXCO INC                     1_HARDERSFIELD_1009
# 1        MARTIGNETTI COMPANIES  1_HARDERSFIELD_10238
# 2        MARTIGNETTI COMPANIES  1_HARDERSFIELD_10239
# 3  M S WALKER INC               1_HARDERSFIELD_10266
# 4  HEAVEN HILL DISTILLERIES      1_HARDERSFIELD_1029
#
#                     Description  SalesQuantity  SalesDollars  TotalSale
# 0       Rebel Yell Variety Pack              1         49.99      49.99
# 1   Layer Cake Primitivo Puglia              2         31.98      63.96
# 2       Cannonball Cab Svgn Cal              1         13.99      13.99
# 3  Klinker Brick Old Vine Znfdl              1         16.99      16.99
# 4  Fulton's Harvest Apple Pie L              1          9.99       9.99

# %%
d5 = sales[['VendorName','InventoryId','Description','SalesQuantity',]].groupby('VendorName').sum()

# %%
d5.head()
# Out:
#                                                                        InventoryId  \
# VendorName
# ADAMBA IMPORTS INTL INC          10_HORNSEY_397934_PITMERDEN_397976_DONCASTER_3...
# ALISA CARR BEVERAGES             76_DONCASTER_9001269_MOUNTMEND_9001166_EANVERN...
# ALTAMAR BRANDS LLC               1_HARDERSFIELD_841969_MOUNTMEND_84121_HARDERSF...
# AMERICAN SPIRITS EXCHANGE                                       50_MOUNTMEND_20789
# AMERICAN VINTAGE BEVERAGE        23_ARBINGTON_521524_PALPERROTH_525532_MOUNTMEN...
#
#                                                                        Description  \
# VendorName
# ADAMBA IMPORTS INTL INC          Vesica Potato VodkaVesica Potato VodkaVesica P...
# ALISA CARR BEVERAGES             Ch Malartic Lagravier 12 RGCh Pichon Longville...
# ALTAMAR BRANDS LLC               Ocho Tequila Plata CorralesTequila Ocho Plata ...
# AMERICAN SPIRITS EXCHANGE                                      Zin-phomaniac Znfdl
# AMERICAN VINTAGE BEVERAGE        TGI Fridays Long Island IcedTGI Fridays Ultimt...
#
#                                  SalesQuantity
# VendorName
# ADAMBA IMPORTS INTL INC                    360
# ALISA CARR BEVERAGES                        52
# ALTAMAR BRANDS LLC                          32
# AMERICAN SPIRITS EXCHANGE                    1
# AMERICAN VINTAGE BEVERAGE                 1141

# %%
#p5d = purchases[['VendorName','Quantity']]
#p5d.head()

# %%
d5.sort_values(by='SalesQuantity',ascending=False).head(10)
# Out:
#                                                                    InventoryId  \
# VendorName
# DIAGEO NORTH AMERICA INC     1_HARDERSFIELD_13841_HARDERSFIELD_16231_HARDER...
# JIM BEAM BRANDS COMPANY      1_HARDERSFIELD_10351_HARDERSFIELD_12391_HARDER...
# MARTIGNETTI COMPANIES        1_HARDERSFIELD_102381_HARDERSFIELD_102391_HARD...
# CONSTELLATION BRANDS INC     1_HARDERSFIELD_112131_HARDERSFIELD_138361_HARD...
# E & J GALLO WINERY           1_HARDERSFIELD_104201_HARDERSFIELD_104211_HARD...
# PERNOD RICARD USA            1_HARDERSFIELD_10361_HARDERSFIELD_26151_HARDER...
# BACARDI USA INC              1_HARDERSFIELD_1261_HARDERSFIELD_1261_HARDERSF...
# SAZERAC CO INC               1_HARDERSFIELD_12811_HARDERSFIELD_17671_HARDER...
# M S WALKER INC               1_HARDERSFIELD_102661_HARDERSFIELD_106031_HARD...
# ULTRA BEVERAGE COMPANY LLP   1_HARDERSFIELD_106261_HARDERSFIELD_113671_HARD...
#
#                                                                    Description  \
# VendorName
# DIAGEO NORTH AMERICA INC     Bulleit 95 RyeBulleit 95 RyeBulleit 95 RyeBull...
# JIM BEAM BRANDS COMPANY      Pinnacle Vodka Gift PakBooker's BourbonJim Bea...
# MARTIGNETTI COMPANIES        Layer Cake Primitivo PugliaCannonball Cab Svgn...
# CONSTELLATION BRANDS INC     Meiomi Pnt NrR Mondavi Private Sel Pnt NrRex G...
# E & J GALLO WINERY           Barefoot Moscato CalBarefoot Moscato CalStarbo...
# PERNOD RICARD USA            Jameson Trilogy PackChivas RegalBallantinesSca...
# BACARDI USA INC              Grey Goose VodkaGrey Goose VodkaDewars White L...
# SAZERAC CO INC               Benchmark Old #8 BourbonBuffalo Trace BourbonB...
# M S WALKER INC               Klinker Brick Old Vine ZnfdlParducci Petite Si...
# ULTRA BEVERAGE COMPANY LLP   MezzaCorona Pnt NrTwo Oceans WstrnCape Svgn Bl...
#
#                              SalesQuantity
# VendorName
# DIAGEO NORTH AMERICA INC            420232
# JIM BEAM BRANDS COMPANY             204921
# MARTIGNETTI COMPANIES               200563
# CONSTELLATION BRANDS INC            180330
# E & J GALLO WINERY                  140777
# PERNOD RICARD USA                   122603
# BACARDI USA INC                     113002
# SAZERAC CO INC                      109766
# M S WALKER INC                      105154
# ULTRA BEVERAGE COMPANY LLP           82861

# %% [markdown]
# Table shows which items had the most sales.
