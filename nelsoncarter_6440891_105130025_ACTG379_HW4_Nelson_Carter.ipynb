# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate
# 0  750mL               8  12.99  2016-01-01
# 1  750mL               7  10.99  2016-01-01

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
begInv_Store.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917          838079.59
# 2               52925          840452.20

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %% [markdown]
# Deliverable 1a

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head()
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852         3291170.24
# 73             162551         3142497.36
# 67             158996         3079578.63
# 66             149314         2973033.90
# 76             140208         2952418.44
# 69             144255         2946726.65
# 38             114368         2232698.77
# 55             119641         2001263.66
# 50              94720         1649808.22
# 79              95330         1503149.48

# %% [markdown]
# Deliverable 1b

# %%
begInv_Brand = begInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()

# %%
begInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head()
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 3545            14499          463823.01
# 1233            12016          432455.84
# 8068            15341          383371.59
# 4261            15499          340823.01
# 3858            13649          327439.51

# %%
begInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 3545            14499          463823.01
# 1233            12016          432455.84
# 8068            15341          383371.59
# 4261            15499          340823.01
# 3858            13649          327439.51
# 2753             4625          286703.75
# 8082             9287          278517.13
# 8680             7066          275503.34
# 2589             6766          270572.34
# 3876            14829          266773.71

# %% [markdown]
# Deliverable 2a

# %%
EndInv = pd.read_csv("EndInvFINAL12-31-16Sample.csv")

# %%
EndInv.head()
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2016-12-31
# 1  750mL       7  36.99  2016-12-31
# 2  750mL       7  38.99  2016-12-31
# 3  750mL       4  34.99  2016-12-31
# 4  750mL       7  14.99  2016-12-31

# %%
EndInv['InvCost01_01_2016'] = EndInv['onHand'] * EndInv['Price']

# %%
EndInv_Store = EndInv[['Store','onHand','InvCost01_01_2016']].groupby('Store').sum()
EndInv_Store.head(2)
# Out:
#        onHand  InvCost01_01_2016
# Store
# 1       79827         1206845.93
# 2       56671          850884.06

# %%
EndInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head()
# Out:
#        onHand  InvCost01_01_2016
# Store
# 50     260717         4887260.68
# 73     164589         3254662.81
# 67     163765         3076114.82
# 34     145829         3074616.75
# 76     143866         2975945.18

# %%
EndInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        onHand  InvCost01_01_2016
# Store
# 50     260717         4887260.68
# 73     164589         3254662.81
# 67     163765         3076114.82
# 34     145829         3074616.75
# 76     143866         2975945.18
# 69     150848         2968678.82
# 66     144579         2860504.99
# 74     166015         2803645.13
# 38     129397         2463906.85
# 55     125584         2234836.35

# %% [markdown]
# Deliverable 2b

# %%
EndInv_Brand = EndInv[['Brand','onHand','InvCost01_01_2016']].groupby('Brand').sum()
EndInv_Store.head(2)
# Out:
#        onHand  InvCost01_01_2016
# Store
# 1       79827         1206845.93
# 2       56671          850884.06

# %%
EndInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head()
# Out:
#        onHand  InvCost01_01_2016
# Brand
# 1233    15047          526494.53
# 3545    16770          502932.30
# 2753     7849          470861.51
# 8068    15608          366631.92
# 3405    12268          355649.32

# %%
EndInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        onHand  InvCost01_01_2016
# Brand
# 1233    15047          526494.53
# 3545    16770          502932.30
# 2753     7849          470861.51
# 8068    15608          366631.92
# 3405    12268          355649.32
# 4261    16769          351981.31
# 2757    11603          336370.97
# 2589     7922          300956.78
# 1376    13180          276648.20
# 2585    10487          272557.13

# %% [markdown]
# Deliverable 3

# %%
dfbegInv = begInv

# %%
dfEndInv = EndInv

# %%
Inventory = pd.merge(left=dfbegInv[['InventoryId','01_01_2016_Qty','Price']], right=dfEndInv[['InventoryId','onHand','InvCost01_01_2016']],how='outer', on=['InventoryId'])

# %%
Inventory.head()
# Out:
#          InventoryId  01_01_2016_Qty  Price  onHand  InvCost01_01_2016
# 0  1_HARDERSFIELD_58             8.0  12.99    11.0             142.89
# 1  1_HARDERSFIELD_60             7.0  10.99     NaN                NaN
# 2  1_HARDERSFIELD_62             6.0  36.99     7.0             258.93
# 3  1_HARDERSFIELD_63             3.0  38.99     7.0             272.93
# 4  1_HARDERSFIELD_72             6.0  34.99     4.0             139.96

# %%
Inventory.fillna(0)
# Out:
#               InventoryId  01_01_2016_Qty  Price  onHand  InvCost01_01_2016
# 0       1_HARDERSFIELD_58             8.0  12.99    11.0             142.89
# 1       1_HARDERSFIELD_60             7.0  10.99     0.0               0.00
# 2       1_HARDERSFIELD_62             6.0  36.99     7.0             258.93
# 3       1_HARDERSFIELD_63             3.0  38.99     7.0             272.93
# 4       1_HARDERSFIELD_72             6.0  34.99     4.0             139.96
# ...                   ...             ...    ...     ...                ...
# 256037  81_PEMBROKE_90087             0.0   0.00     3.0            1409.97
# 256038  81_PEMBROKE_90088             0.0   0.00     3.0             404.97
# 256039  81_PEMBROKE_90089             0.0   0.00     3.0             359.97
# 256040  81_PEMBROKE_90090             0.0   0.00     3.0            1949.97
# 256041  81_PEMBROKE_90604             0.0   0.00     2.0             239.98
#
# [256042 rows x 5 columns]

# %% [markdown]
# Deliverable 4a

# %%
Purchases = pd.read_csv("PurchasesFINAL12-31-16Sample.csv")

# %%
Purchases.head()
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0  69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1  34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
# 3      5_SUTTON_3348      5   3348           Bombay Sapphire Gin  1.75L
# 4   30_CULCHETH_4903     30   4903          Bacardi Superior Rum  200mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2015-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 2           388  ATLANTIC IMPORTING COMPANY       8169  2015-12-24
# 3           480  BACARDI USA INC                  8106  2015-12-20
# 4           480  BACARDI USA INC                  8106  2015-12-20
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
Purchases.sort_values(by='Dollars',ascending=False).head(10)
# Out:
#                InventoryId  Store  Brand                   Description   Size  \
# 503213   27_MOUNTMEND_3858     27   3858              Grey Goose Vodka  750mL
# 827869    27_MOUNTMEND_126     27    126              Grey Goose Vodka  Liter
# 820905  69_MOUNTMEND_42188     69  42188  Moet & Chandon Nectar Imp Rs  750mL
# 741650   50_MOUNTMEND_2277     50   2277       Kilbeggan Irish Whiskey  750mL
# 637575   50_MOUNTMEND_3545     50   3545               Ketel One Vodka  1.75L
# 503811     33_HORNSEY_3858     33   3858              Grey Goose Vodka  750mL
# 127802   34_PITMERDEN_2585     34   2585         Jameson Irish Whiskey  750mL
# 518029   69_MOUNTMEND_8068     69   8068              Absolut 80 Proof  1.75L
# 810476     33_HORNSEY_1233     33   1233       Jack Daniels No 7 Black  1.75L
# 967833   61_AETHELNEY_2589     61   2589         Jameson Irish Whiskey  1.75L
#
#         VendorNumber                   VendorName  PONumber      PODate  \
# ...

# %% [markdown]
# Deliverable 4b

# %%
Invoices = pd.read_csv("InvoicePurchases12-31-16Sample.csv")

# %%
Invoices.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN
# 3  2015-12-20  2016-02-05     10100  137483.78  2935.20      NaN
# 4  2015-12-24  2016-02-12      1935   15527.25   429.20      NaN

# %%
Invoices.sort_values(by='Freight',ascending=False).head(10)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 4728          3960  DIAGEO NORTH AMERICA INC     2016-11-15     12833
# 4627          3960  DIAGEO NORTH AMERICA INC     2016-11-12     12771
# 2822          3960  DIAGEO NORTH AMERICA INC     2016-07-16     10936
# 4521          3960  DIAGEO NORTH AMERICA INC     2016-11-03     12618
# 3025          3960  DIAGEO NORTH AMERICA INC     2016-08-01     11191
# 4829          3960  DIAGEO NORTH AMERICA INC     2016-11-29     12981
# 2125          3960  DIAGEO NORTH AMERICA INC     2016-06-06     10260
# 3129          3960  DIAGEO NORTH AMERICA INC     2016-08-03     11300
# 5037          3960  DIAGEO NORTH AMERICA INC     2016-12-07     13190
# 2924          3960  DIAGEO NORTH AMERICA INC     2016-07-26     11028
#
#           PODate     PayDate  Quantity     Dollars  Freight        Approval
# 4728  2016-10-30  2016-12-19    141660  1660435.88  8468.22  Frank Delahunt
# ...

# %% [markdown]
# Deliverable 4c

# %%
Invoices['FreightPer$'] = Invoices['Freight'] / Invoices['Dollars']

# %%
Invoices.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval  FreightPer$
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN     0.016195
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN     0.060975
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN     0.043246
# 3  2015-12-20  2016-02-05     10100  137483.78  2935.20      NaN     0.021349
# 4  2015-12-24  2016-02-12      1935   15527.25   429.20      NaN     0.027642

# %%
Invoices.sort_values(by='FreightPer$',ascending=False).head(5)
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 36          4848  LAIRD & CO                   2016-01-07      8143
# 88         90058  ZORVINO VINEYARDS            2016-01-09      8206
# 8           1273  CALEDONIA SPIRITS INC        2016-01-06      8172
# 33          4550  KLIN SPIRITS LLC             2016-01-07      8196
# 58          7255                   PSP WINES   2016-01-11      8198
#
#         PODate     PayDate  Quantity  Dollars  Freight Approval  FreightPer$
# 36  2015-12-22  2016-02-06        12   120.72    13.91      NaN     0.115225
# 88  2015-12-25  2016-02-12        23   186.93    21.04      NaN     0.112556
# 8   2015-12-24  2016-02-15         5   146.80    15.53      NaN     0.105790
# 33  2015-12-25  2016-02-17         7    98.49     9.65      NaN     0.097979
# 58  2015-12-25  2016-02-12        11    66.33     6.09      NaN     0.091814

# %%
Invoices.sort_values(by='FreightPer$',ascending=True).head(5)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 3724          2396  BLACK PRINCE DISTILLERY INC  2016-09-19     11904
# 3010          2396  BLACK PRINCE DISTILLERY INC  2016-07-27     11139
# 5081          7749  R.P.IMPORTS INC              2016-12-11     13228
# 1001          1003  BRONCO WINE COMPANY          2016-03-20      9164
# 4288          9622  WEIN BAUER INC               2016-10-13     12358
#
#           PODate     PayDate  Quantity  Dollars  Freight Approval  FreightPer$
# 3724  2016-09-01  2016-10-16        12    52.08     0.23      NaN     0.004416
# 3010  2016-07-11  2016-08-29        12    52.08     0.23      NaN     0.004416
# 5081  2016-11-25  2017-01-16         1    13.51     0.06      NaN     0.004441
# 1001  2016-03-02  2016-04-25        12    31.44     0.14      NaN     0.004453
# 4288  2016-09-27  2016-11-20        12    85.08     0.38      NaN     0.004466

# %% [markdown]
# Deliverable 4d

# %%
Invoices['Total Freight'] = Invoices['Freight'] * Invoices['Quantity']

# %%
Invoices.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval  FreightPer$  \
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN     0.016195
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN     0.060975
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN     0.043246
# 3  2015-12-20  2016-02-05     10100  137483.78  2935.20      NaN     0.021349
# 4  2015-12-24  2016-02-12      1935   15527.25   429.20      NaN     0.027642
#
#    Total Freight
# 0          20.82
# 1         128.55
# 2          23.05
# 3    29645520.00
# ...

# %%
Invoices.sort_values(by='Freight',ascending=True).head(5)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 331           5612  MILTONS DISTRIBUTING CO      2016-01-31      8476
# 842           5270  MANGO BOTTLING INC           2016-03-05      8931
# 3460          5612  MILTONS DISTRIBUTING CO      2016-08-22     11532
# 413          90052  HAUNTING WHISPER VYDS        2016-02-07      8538
# 1710         90046  CANDIA VINEYARDS             2016-05-06      9833
#
#           PODate     PayDate  Quantity  Dollars  Freight Approval  \
# 331   2016-01-14  2016-03-13         1     4.14     0.02      NaN
# 842   2016-02-15  2016-04-11         1     6.47     0.03      NaN
# 3460  2016-08-07  2016-10-09         1     5.22     0.03      NaN
# 413   2016-01-19  2016-03-13         1     8.27     0.04      NaN
# 1710  2016-04-18  2016-06-06         1    10.06     0.05      NaN
#
#       FreightPer$  Total Freight  FreightPerUnit
# 331      0.004831           0.02            0.02
# ...

# %% [markdown]
# Deliverable 4e

# %%
Invoices['FreightPerUnit'] = Invoices['Freight'] / Invoices['Quantity']

# %%
Invoices.sort_values(by='Freight',ascending=True).head(5)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 331           5612  MILTONS DISTRIBUTING CO      2016-01-31      8476
# 842           5270  MANGO BOTTLING INC           2016-03-05      8931
# 3460          5612  MILTONS DISTRIBUTING CO      2016-08-22     11532
# 413          90052  HAUNTING WHISPER VYDS        2016-02-07      8538
# 1710         90046  CANDIA VINEYARDS             2016-05-06      9833
#
#           PODate     PayDate  Quantity  Dollars  Freight Approval  \
# 331   2016-01-14  2016-03-13         1     4.14     0.02      NaN
# 842   2016-02-15  2016-04-11         1     6.47     0.03      NaN
# 3460  2016-08-07  2016-10-09         1     5.22     0.03      NaN
# 413   2016-01-19  2016-03-13         1     8.27     0.04      NaN
# 1710  2016-04-18  2016-06-06         1    10.06     0.05      NaN
#
#       FreightPer$  Total Freight  FreightPerUnit
# 331      0.004831           0.02            0.02
# ...

# %% [markdown]
# Compared to Deliverable 4c the FreightPer$ is higher for all 5 companies shown

# %% [markdown]
# Deliverable 5

# %%
DecSales = pd.read_csv("2017PurchasePricesDec.csv")

# %% [markdown]
# Tried to merge December sales with Purchases but it said not enough memory to support the merging of the files

# %%
DecSales['%Profit'] = 1-(DecSales['PurchasePrice'] / DecSales['Price'])

# %%
DecSales.head()
# Out:
#    Brand                  Description  Price   Size Volume  Classification  \
# 0     58  Gekkeikan Black & Gold Sake  12.99  750mL    750               1
# 1     62     Herradura Silver Tequila  36.99  750mL    750               1
# 2     63   Herradura Reposado Tequila  38.99  750mL    750               1
# 3     72         No. 3 London Dry Gin  34.99  750mL    750               1
# 4     75    Three Olives Tomato Vodka  14.99  750mL    750               1
#
#    PurchasePrice  VendorNumber                   VendorName   %Profit
# 0           9.28          8320  SHAW ROSS INT L IMP LTD      0.285604
# 1          28.67          1128  BROWN-FORMAN CORP            0.224926
# 2          30.46          1128  BROWN-FORMAN CORP            0.218774
# 3          26.11          9165  ULTRA BEVERAGE COMPANY LLP   0.253787
# 4          10.94          7245  PROXIMO SPIRITS INC.         0.270180

# %%
Top 5 most profitable bottles

# %%
DecSales.sort_values(by='%Profit',ascending=False).head(5)
# Out:
#       Brand                   Description  Price   Size Volume  \
# 8799  22975  L.A. Cetto Nebbiolo Priv Rsv  23.99  750mL    750
# 6218  19835                 Luiano Rosato  12.99  375mL    375
# 7189  16935        Martinotti Metodo Brut  17.99  750mL    750
# 4969  38467   Bertiol Prosecco Conegliano  16.99  750mL    750
# 2331  18627                 Viberti Chard  16.99  750mL    750
#
#       Classification  PurchasePrice  VendorNumber  \
# 8799               2           3.62          9165
# 6218               2           2.16          9165
# 7189               2           3.10         90024
# 4969               2           2.93          9165
# 2331               2           3.01          9165
#
#                        VendorName   %Profit
# 8799  ULTRA BEVERAGE COMPANY LLP   0.849104
# 6218  ULTRA BEVERAGE COMPANY LLP   0.833718
# 7189  VINILANDIA USA               0.827682
# 4969  ULTRA BEVERAGE COMPANY LLP   0.827546
# 2331  ULTRA BEVERAGE COMPANY LLP   0.822837
