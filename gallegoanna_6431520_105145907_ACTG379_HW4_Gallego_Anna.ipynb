# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price startDate
# 0  750mL       8  12.99  1/1/2016
# 1  750mL       7  10.99  1/1/2016

# %%
begInv = begInv.rename(columns = {'onHand':'Beginning Quantity'})
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  Beginning Quantity  Price startDate
# 0  750mL                   8  12.99  1/1/2016
# 1  750mL                   7  10.99  1/1/2016

# %%
begInv['InvCost01_01_2016'] = begInv['Beginning Quantity'] * begInv['Price']
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  Beginning Quantity  Price startDate  InvCost01_01_2016
# 0  750mL                   8  12.99  1/1/2016             103.92
# 1  750mL                   7  10.99  1/1/2016              76.93

# %%
endInv = pd.read_csv("EndInvFINAL12-31-16Sample.csv")
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  12/31/2016
# 1  750mL       7  36.99  12/31/2016

# %%
endInv = endInv.rename(columns = {'onHand':'Ending Quantity'})
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  Ending Quantity  Price     endDate
# 0  750mL               11  12.99  12/31/2016
# 1  750mL                7  36.99  12/31/2016

# %%
endInv['InvCost01_01_2016'] = endInv['Ending Quantity'] * endInv['Price']
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  Ending Quantity  Price     endDate  InvCost01_01_2016
# 0  750mL               11  12.99  12/31/2016             142.89
# 1  750mL                7  36.99  12/31/2016             258.93

# %% [markdown]
# # Deliverable 1

# %%
begInv_Store = begInv[['Store','Beginning Quantity','InvCost01_01_2016']].groupby('Store').sum()

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        Beginning Quantity  InvCost01_01_2016
# Store
# 34                 153852       3,291,170.24
# 73                 162551       3,142,497.36
# 67                 158996       3,079,578.63
# 66                 149314       2,973,033.90
# 76                 140208       2,952,418.44
# 69                 144255       2,946,726.65
# 38                 114368       2,232,698.77
# 55                 119641       2,001,263.66
# 50                  94720       1,649,808.22
# 79                  95330       1,503,149.48

# %%
begInv_Brand = begInv[['Brand','Beginning Quantity','InvCost01_01_2016']].groupby('Brand').sum()
begInv_Brand.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        Beginning Quantity  InvCost01_01_2016
# Brand
# 3545                14499         463,823.01
# 1233                12016         432,455.84
# 8068                15341         383,371.59
# 4261                15499         340,823.01
# 3858                13649         327,439.51
# 2753                 4625         286,703.75
# 8082                 9287         278,517.13
# 8680                 7066         275,503.34
# 2589                 6766         270,572.34
# 3876                14829         266,773.71

# %% [markdown]
# # Deliverable 2

# %%
endInv_Store = endInv[['Store','Ending Quantity','InvCost01_01_2016']].groupby('Store').sum()
endInv_Store.head(2)
endInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
endInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# Out:
#        Ending Quantity  InvCost01_01_2016
# Store
# 50              260717       4,887,260.68
# 73              164589       3,254,662.81
# 67              163765       3,076,114.82
# 34              145829       3,074,616.75
# 76              143866       2,975,945.18
# 69              150848       2,968,678.82
# 66              144579       2,860,504.99
# 74              166015       2,803,645.13
# 38              129397       2,463,906.85
# 55              125584       2,234,836.35

# %%
endInv_Brand = endInv[['Brand','Ending Quantity','InvCost01_01_2016']].groupby('Brand').sum()
endInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        Ending Quantity  InvCost01_01_2016
# Brand
# 1233             15047         526,494.53
# 3545             16770         502,932.30
# 2753              7849         470,861.51
# 8068             15608         366,631.92
# 3405             12268         355,649.32
# 4261             16769         351,981.31
# 2757             11603         336,370.97
# 2589              7922         300,956.78
# 1376             13180         276,648.20
# 2585             10487         272,557.13

# %% [markdown]
# # Deliverable 3

# %%
merged1 = pd.merge(left=begInv, right=endInv, how='left', on=['InventoryId'])
merged1["Beginning Total"] = (merged1["Beginning Quantity"] * merged1["Price_x"])
merged1["Ending Total"] = (merged1["Ending Quantity"] * merged1["Price_y"])
merged1 = merged1[['InventoryId','Beginning Quantity', 'Beginning Total', 'Ending Quantity', 'Ending Total']]
merged1 = merged1.fillna(0)
merged1.head()
# Out:
#          InventoryId  Beginning Quantity  Beginning Total  Ending Quantity  \
# 0  1_HARDERSFIELD_58                   8           103.92            11.00
# 1  1_HARDERSFIELD_60                   7            76.93             0.00
# 2  1_HARDERSFIELD_62                   6           221.94             7.00
# 3  1_HARDERSFIELD_63                   3           116.97             7.00
# 4  1_HARDERSFIELD_72                   6           209.94             4.00
#
#    Ending Total
# 0        142.89
# 1          0.00
# 2        258.93
# 3        272.93
# 4        139.96

# %%
len(merged1)
# Out:
# 206529

# %% [markdown]
# # Deliverable 4a

# %%
purchases = pd.read_csv("PurchasesFINAL 12-31-16Sample.csv")
invoice_purchases = pd.read_csv("InvoicePurchases12-31-16Sample.csv")
purchases.head()
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0  69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1  34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
# 3      5_SUTTON_3348      5   3348           Bombay Sapphire Gin  1.75L
# 4   30_CULCHETH_4903     30   4903          Bacardi Superior Rum  200mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  12/21/2015
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  12/22/2015
# 2           388  ATLANTIC IMPORTING COMPANY       8169  12/24/2015
# 3           480  BACARDI USA INC                  8106  12/20/2015
# 4           480  BACARDI USA INC                  8106  12/20/2015
#
#   ReceivingDate InvoiceDate    PayDate  PurchasePrice  Quantity  Dollars  \
# 0      1/2/2016    1/4/2016  2/16/2016          35.71         6   214.26
# 1      1/2/2016    1/7/2016  2/21/2016           9.41         5    47.05
# 2      1/2/2016    1/9/2016  2/16/2016          21.32         5   106.60
# 3      1/2/2016   1/12/2016   2/5/2016          22.38         6   134.28
# 4      1/1/2016   1/12/2016   2/5/2016           2.87        48   137.76
#
#    Classification
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
purchases['InvoiceDate'] = pd.to_datetime(purchases['InvoiceDate'])
vendor_purchases = purchases[purchases['InvoiceDate'].dt.year == 2016]
vendor_purchases = purchases.groupby(['VendorNumber', 'VendorName']).agg({'Dollars': 'sum'}).reset_index()
vendor_purchases_grouped = purchases.sort_values(by='Dollars',ascending=False).head(10)
vendor_purchases_grouped= vendor_purchases_grouped[['VendorNumber','VendorName', 'Dollars']]
vendor_purchases_grouped.head(10)
# Out:
#         VendorNumber                   VendorName   Dollars
# 503213           480  BACARDI USA INC             36,517.35
# 827869           480  BACARDI USA INC             32,465.68
# 820905          8112  MOET HENNESSY USA INC       32,445.54
# 741650         12546  JIM BEAM BRANDS COMPANY     30,534.79
# 637575          3960  DIAGEO NORTH AMERICA INC    26,727.69
# 503811           480  BACARDI USA INC             25,961.97
# 127802         17035  PERNOD RICARD USA           23,989.62
# 518029         17035  PERNOD RICARD USA           22,599.36
# 810476          1128  BROWN-FORMAN CORP           20,727.03
# 967833         17035  PERNOD RICARD USA           19,901.72

# %% [markdown]
# # Deliverable 4b

# %%
vendor_invoice_purchases = invoice_purchases[['VendorNumber','VendorName','Freight']].groupby('VendorNumber').sum()
vendor_invoice_grouped = vendor_invoice_purchases.sort_values(by='Freight',ascending=False).head(10)
vendor_invoice_grouped.head(10)
# Out:
#                                                      VendorName    Freight
# VendorNumber
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC... 257,032.07
# 4425          MARTIGNETTI COMPANIES MARTIGNETTI COMPANIESMAR... 144,929.24
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM... 123,880.97
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ... 123,780.22
# 480           BACARDI USA INC            BACARDI USA INC    ...  89,286.27
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND...  79,528.99
# 1128          BROWN-FORMAN CORP          BROWN-FORMAN CORP  ...  68,601.68
# 9165          ULTRA BEVERAGE COMPANY LLP ULTRA BEVERAGE COMP...  68,054.70
# 3252          E & J GALLO WINERY         E & J GALLO WINERY ...  61,966.91
# 9552          M S WALKER INC             M S WALKER INC     ...  55,551.82

# %% [markdown]
# # Deliverable 4c

# %%
vendor_purchases1 =invoice_purchases[invoice_purchases["Dollars"] >= 250000]
vendor_purchases1['InvoiceDate'] = pd.to_datetime(vendor_purchases1['InvoiceDate'])
vendor_purchases = purchases[purchases['InvoiceDate'].dt.year == 2016]
# Out:
# C:\Users\annag\AppData\Local\Temp\ipykernel_30156\3018606685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendor_purchases1['InvoiceDate'] = pd.to_datetime(vendor_purchases1['InvoiceDate'])

# %%
vendor_purchases1["Freight Rate"] = (vendor_purchases1["Freight"]/vendor_purchases1["Dollars"])
vendor_purchases1["FreightPerUnit"] = (vendor_purchases1["Freight"]/vendor_purchases1["Quantity"])
vendor_purchases1_grouped = vendor_purchases1[['VendorNumber','VendorName','Freight','Dollars','Quantity','Freight Rate','FreightPerUnit']].groupby('VendorNumber').sum()
vendor_purchases_sorted = vendor_purchases1_grouped.sort_values(by='Freight Rate',ascending=False).head(10)
vendor_purchases_sorted.head(10)
# Out:
# C:\Users\annag\AppData\Local\Temp\ipykernel_30156\2683066835.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendor_purchases1["Freight Rate"] = (vendor_purchases1["Freight"]/vendor_purchases1["Dollars"])
# C:\Users\annag\AppData\Local\Temp\ipykernel_30156\2683066835.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vendor_purchases1["FreightPerUnit"] = (vendor_purchases1["Freight"]/vendor_purchases1["Quantity"])
#                                                      VendorName    Freight  \
# VendorNumber
# 4425          MARTIGNETTI COMPANIESMARTIGNETTI COMPANIESMART... 139,012.99
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM... 119,877.31
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC... 249,954.76
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ... 117,037.87
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND...  62,069.80
# 480           BACARDI USA INC            BACARDI USA INC    ...  72,547.44
# 1128          BROWN-FORMAN CORP          BROWN-FORMAN CORP  ...  43,517.45
# 9165          ULTRA BEVERAGE COMPANY LLP ULTRA BEVERAGE COMP...  33,567.44
# 3252          E & J GALLO WINERY         E & J GALLO WINERY ...  26,985.48
# 8112          MOET HENNESSY USA INC      MOET HENNESSY USA I...  16,609.80
#
#                    Dollars  Quantity  Freight Rate  FreightPerUnit
# VendorNumber
# 4425         27,432,418.49   2600730          0.26            2.77
# 12546        23,956,423.83   2715232          0.26            2.31
# 3960         50,556,954.94   5422558          0.26            2.36
# 17035        23,267,207.39   1582397          0.25            3.60
# 1392         12,326,756.42   1825237          0.19            1.26
# 480          14,728,714.80   1165943          0.18            2.29
# 1128          8,755,247.09    627082          0.14            1.95
# 9165          6,527,827.47    522282          0.11            1.35
# 3252          5,474,544.72    832842          0.09            0.62
# 8112          3,356,086.94    140015          0.05            1.19

# %%
vendor_purchases_sorted.sort_values(by='Freight Rate').tail(5).sort_values(by='Freight Rate', ascending = True)
# Out:
#                                                      VendorName    Freight  \
# VendorNumber
# 1392          CONSTELLATION BRANDS INC   CONSTELLATION BRAND...  62,069.80
# 17035         PERNOD RICARD USA          PERNOD RICARD USA  ... 117,037.87
# 3960          DIAGEO NORTH AMERICA INC   DIAGEO NORTH AMERIC... 249,954.76
# 12546         JIM BEAM BRANDS COMPANY    JIM BEAM BRANDS COM... 119,877.31
# 4425          MARTIGNETTI COMPANIESMARTIGNETTI COMPANIESMART... 139,012.99
#
#                    Dollars  Quantity  Freight Rate  FreightPerUnit
# VendorNumber
# 1392         12,326,756.42   1825237          0.19            1.26
# 17035        23,267,207.39   1582397          0.25            3.60
# 3960         50,556,954.94   5422558          0.26            2.36
# 12546        23,956,423.83   2715232          0.26            2.31
# 4425         27,432,418.49   2600730          0.26            2.77

# %% [markdown]
# # Deliverable 4d

# %%
vendor_purchases2 = invoice_purchases.drop(invoice_purchases[invoice_purchases['VendorName'] == 'EDRINGTON AMERICAS'].index)
vendor_purchases2 = vendor_purchases2[vendor_purchases2["Freight"]>=100]
vendor_purchases2 = vendor_purchases2[vendor_purchases2["Quantity"]<=1000]
vendor_purchases2 = vendor_purchases2.groupby(['VendorNumber','VendorName']).agg({'Freight':'sum','Dollars':'sum','Quantity':'sum'}).sort_values(by='Freight',ascending=False)
vendor_purchases2.head()
# Out:
#                                           Freight    Dollars  Quantity
# VendorNumber VendorName
# 2561         EDRINGTON AMERICAS          2,944.67 570,627.52     18120
# 8664         STOLI GROUP,(USA) LLC         349.02  14,299.98       975
# 7239         REMY COINTREAU USA INC        348.07   7,515.38       382
# 653          STATE WINE & SPIRITS          303.70   5,544.89       541
# 6785         PALM BAY INTERNATIONAL INC    242.73   5,533.18       715

# %% [markdown]
# # Deliverable 4e

# %%
vendor_purchases2 = invoice_purchases.drop(invoice_purchases[invoice_purchases['VendorName'] == 'EDRINGTON AMERICAS'].index)
vendor_purchases2["Freight Rate"] = (vendor_purchases2["Freight"]/vendor_purchases2["Dollars"])
vendor_purchases2["FreightPerUnit"] = (vendor_purchases2["Freight"]/vendor_purchases2["Quantity"])
vendor_purchases2 = vendor_purchases2[vendor_purchases2["Freight"]>=100]
vendor_purchases2 = vendor_purchases2[vendor_purchases2["Quantity"]<=1000]
vendor_purchases2 = vendor_purchases2.groupby(['VendorNumber','VendorName']).agg({'Freight':'sum','Dollars':'sum','Quantity':'sum','Freight Rate':'sum','FreightPerUnit':'sum'}).sort_values(by='Freight',ascending=False)
vendor_purchases2.head()
# Out:
#                                           Freight    Dollars  Quantity  \
# VendorNumber VendorName
# 2561         EDRINGTON AMERICAS          2,944.67 570,627.52     18120
# 8664         STOLI GROUP,(USA) LLC         349.02  14,299.98       975
# 7239         REMY COINTREAU USA INC        348.07   7,515.38       382
# 653          STATE WINE & SPIRITS          303.70   5,544.89       541
# 6785         PALM BAY INTERNATIONAL INC    242.73   5,533.18       715
#
#                                           Freight Rate  FreightPerUnit
# VendorNumber VendorName
# 2561         EDRINGTON AMERICAS                   0.14            4.82
# 8664         STOLI GROUP,(USA) LLC                0.02            0.36
# 7239         REMY COINTREAU USA INC               0.05            0.91
# 653          STATE WINE & SPIRITS                 0.05            0.56
# 6785         PALM BAY INTERNATIONAL INC           0.04            0.34

# %% [markdown]
# The rate and freight per unit is alot less in 4e than in 4c.

# %% [markdown]
# # Deliverable 5

# %%
sales = pd.read_csv("SalesFINAL 12-31-16Sample.csv")
sales["Revenue"] = sales["SalesPrice"] * sales["SalesQuantity"]
sales_grouped = sales[["VendorNo",'VendorName',"Revenue",]].groupby(["VendorNo",'VendorName']).sum()
sales_sorted = sales_grouped.sort_values(by="Revenue", ascending=False)
sales_sorted.head(10)
# Out:
#                                           Revenue
# VendorNo VendorName
# 3960     DIAGEO NORTH AMERICA INC    5,333,892.56
# 4425     MARTIGNETTI COMPANIES       3,169,065.81
# 12546    JIM BEAM BRANDS COMPANY     2,487,675.19
# 17035    PERNOD RICARD USA           2,449,328.80
# 480      BACARDI USA INC             1,935,245.08
# 1392     CONSTELLATION BRANDS INC    1,914,760.47
# 3252     E & J GALLO WINERY          1,446,875.44
# 1128     BROWN-FORMAN CORP           1,437,455.00
# 9165     ULTRA BEVERAGE COMPANY LLP  1,405,457.91
# 9552     M S WALKER INC              1,205,760.39

# %% [markdown]
# I decided to do an analysis of the top ten vendors who made the most in revenue. Diageo North America Inc earned $5,333,892.56 in revenue from 2016.
