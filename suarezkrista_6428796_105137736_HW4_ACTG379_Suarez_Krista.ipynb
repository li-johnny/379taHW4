# %% [markdown]
# # Import PANDAS Library

# %% [markdown]
# Notice that we are using pd as an abbreviation so each time we want to use the PANDAS library, we can simply type pd instead of pandas.

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Import Dataset (either full dataset or simplified)

# %% [markdown]
# You can use either set of datafiles (full or simplified). In the past some students' computers could not handle the full dataset. If you worry that your computer will not handle the full dataset (or if you find your code is running very slow), use the simplified version.
#
# The simplified version was created by taking a sample of the full data; hence the simplified files have "Sample" added to the end of the file names. Some files were not large to begin with and didn't need to be reduced. Those files do not have Sample added to the end of the file name.

# %% [markdown]
# ## Adjust the file address below to match your computer.

# %% [markdown]
# You will want to replace the begining of the address below (i.e., everything before OneDrive - Oregon State University/)

# %%
begInv = pd.read_csv("BegInvFINAL12-31-16Sample.csv")

# %%
begInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2016-01-01
# 1  750mL       7  10.99  2016-01-01

# %% [markdown]
# ## Deliverable 1a answer

# %%
begInv = begInv.rename(columns = {'onHand':'01_01_2016_Qty'})
begInv.head(2)
#renaming on hand column to reflect the reality of the column, the qty on 1/1/2026
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate
# 0  750mL               8  12.99  2016-01-01
# 1  750mL               7  10.99  2016-01-01

# %%
begInv['InvCost01_01_2016'] = begInv['01_01_2016_Qty'] * begInv['Price']
begInv.head(2)
#qty times price gives us how much that inv costed then
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
#
#     Size  01_01_2016_Qty  Price   startDate  InvCost01_01_2016
# 0  750mL               8  12.99  2016-01-01             103.92
# 1  750mL               7  10.99  2016-01-01              76.93

# %%
begInv_Store = begInv[['Store','01_01_2016_Qty','InvCost01_01_2016']].groupby('Store').sum()
begInv_Store.head(2)
#pulling the store, the qty, the cost, grouping by store, and summing it
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 1               49917         838,079.59
# 2               52925         840,452.20

# %%
begInv_Store.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
#sorting the values by the cost in descending order then only taking the first 10 to get the top 10 stores in terms of inventory cost
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %% [markdown]
# ### Alternative way to get the answer

# %%
begInv_Store.sort_values(by='InvCost01_01_2016').tail(10).sort_values(by='InvCost01_01_2016', ascending = False)
# did tail since the default is ascending order and the last 10 would be the most. Need to sort still since it would be in reverse order.
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Store
# 34             153852       3,291,170.24
# 73             162551       3,142,497.36
# 67             158996       3,079,578.63
# 66             149314       2,973,033.90
# 76             140208       2,952,418.44
# 69             144255       2,946,726.65
# 38             114368       2,232,698.77
# 55             119641       2,001,263.66
# 50              94720       1,649,808.22
# 79              95330       1,503,149.48

# %% [markdown]
# ## Deliverable 1b

# %%
#code brought in from 1a and store was changed to brand. 
begInv_Brand = begInv[['Brand','01_01_2016_Qty','InvCost01_01_2016']].groupby('Brand').sum()
begInv_Brand.head(2)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 58                281           3,650.19
# 60                288           3,165.12

# %%
begInv_Brand.sort_values(by='InvCost01_01_2016',ascending=False).head(10)
# Out:
#        01_01_2016_Qty  InvCost01_01_2016
# Brand
# 3545            14499         463,823.01
# 1233            12016         432,455.84
# 8068            15341         383,371.59
# 4261            15499         340,823.01
# 3858            13649         327,439.51
# 2753             4625         286,703.75
# 8082             9287         278,517.13
# 8680             7066         275,503.34
# 2589             6766         270,572.34
# 3876            14829         266,773.71

# %% [markdown]
# ## Deliverable 2a

# %%
#need to bring in end inventory file
endInv = pd.read_csv("EndInvFINAL12-31-16Sample.csv")
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2016-12-31
# 1  750mL       7  36.99  2016-12-31

# %%
endInv = endInv.rename(columns = {'onHand':'12_31_2016_Qty'})
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate
# 0  750mL              11  12.99  2016-12-31
# 1  750mL               7  36.99  2016-12-31

# %%
endInv['InvCost12_31_2016'] = endInv['12_31_2016_Qty'] * endInv['Price']
endInv.head(2)
# Out:
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
#
#     Size  12_31_2016_Qty  Price     endDate  InvCost12_31_2016
# 0  750mL              11  12.99  2016-12-31             142.89
# 1  750mL               7  36.99  2016-12-31             258.93

# %%
endInv_Store = endInv[['Store','12_31_2016_Qty','InvCost12_31_2016']].groupby('Store').sum()
endInv_Store.head(2)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 1               79827       1,206,845.93
# 2               56671         850,884.06

# %%
endInv_Store.sort_values(by='InvCost12_31_2016',ascending=False).head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Store
# 50             260717       4,887,260.68
# 73             164589       3,254,662.81
# 67             163765       3,076,114.82
# 34             145829       3,074,616.75
# 76             143866       2,975,945.18
# 69             150848       2,968,678.82
# 66             144579       2,860,504.99
# 74             166015       2,803,645.13
# 38             129397       2,463,906.85
# 55             125584       2,234,836.35

# %% [markdown]
# ## Deliverable 2b

# %%
endInv_Brand = endInv[['Brand','12_31_2016_Qty','InvCost12_31_2016']].groupby('Brand').sum()
endInv_Brand.head(2)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Brand
# 58                385           5,001.15
# 60                146           1,604.54

# %%
endInv_Brand.sort_values(by='InvCost12_31_2016',ascending=False).head(10)
# Out:
#        12_31_2016_Qty  InvCost12_31_2016
# Brand
# 1233            15047         526,494.53
# 3545            16770         502,932.30
# 2753             7849         470,861.51
# 8068            15608         366,631.92
# 3405            12268         355,649.32
# 4261            16769         351,981.31
# 2757            11603         336,370.97
# 2589             7922         300,956.78
# 1376            13180         276,648.20
# 2585            10487         272,557.13

# %% [markdown]
# ## Deliverable 3

# %%
merge3 = pd.merge(left=begInv[["InventoryId", "01_01_2016_Qty", "InvCost01_01_2016"]], right=endInv[["12_31_2016_Qty", "InvCost12_31_2016", "InventoryId"]], how='outer', on=["InventoryId"])
merge3.head(2)
# Out:
#          InventoryId  01_01_2016_Qty  InvCost01_01_2016  12_31_2016_Qty  \
# 0  1_HARDERSFIELD_58            8.00             103.92           11.00
# 1  1_HARDERSFIELD_60            7.00              76.93             NaN
#
#    InvCost12_31_2016
# 0             142.89
# 1                NaN

# %%
merge3 = merge3.fillna(0)

# %%
merge3.head()
# Out:
#          InventoryId  01_01_2016_Qty  InvCost01_01_2016  12_31_2016_Qty  \
# 0  1_HARDERSFIELD_58            8.00             103.92           11.00
# 1  1_HARDERSFIELD_60            7.00              76.93            0.00
# 2  1_HARDERSFIELD_62            6.00             221.94            7.00
# 3  1_HARDERSFIELD_63            3.00             116.97            7.00
# 4  1_HARDERSFIELD_72            6.00             209.94            4.00
#
#    InvCost12_31_2016
# 0             142.89
# 1               0.00
# 2             258.93
# 3             272.93
# 4             139.96

# %% [markdown]
# ## Deliverable 4a

# %%
purchases = pd.read_csv("PurchasesFINAL12-31-16Sample.csv")
purchases.head(2)
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0  69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1  34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2015-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    2016-01-02  2016-01-04  2016-02-16          35.71         6   214.26
# 1    2016-01-02  2016-01-07  2016-02-21           9.41         5    47.05
#
#    Classification
# 0               1
# 1               1

# %%
vendors_grouped = purchases.groupby("VendorNumber").sum("Dollars")
vendors_grouped.head()
# Out:
#               Store   Brand  PONumber  PurchasePrice  Quantity   Dollars  \
# VendorNumber
# 2               253  361912     38413          74.86       101  1,751.30
# 54               74     990     13148         105.07         1    105.07
# 60             9909  987756   2964055       4,052.67      1861 30,175.00
# 105            1257  187593    253417         808.87       125  4,388.99
# 200             135  102871     58518          46.45        84    764.52
#
#               Classification
# VendorNumber
# 2                          8
# 54                         1
# 60                       250
# 105                       23
# 200                       10

# %%
sorted_vendors = vendors_grouped.sort_values(by="Dollars", ascending = False)
sorted_vendors.head(10)
# Out:
#                 Store       Brand    PONumber  PurchasePrice  Quantity  \
# VendorNumber
# 3960          4492412   424232145  1129084922   1,658,657.02   2297321
# 4425          3470126  1645180827   826088134     819,826.08   1115923
# 12546         3442874   306514871   875162030   1,033,143.87   1155665
# 17035         2014219   280354410   501427472     847,211.45    692444
# 480           1698603   172316736   427622772     550,546.66    599721
# 1392          3434559  1460616876   866146157     556,347.16    978758
# 1128          1112576    92171488   275646240     458,919.02    423866
# 9165          1652464   615955687   389174208     557,950.57    454455
# 3252          3048616  1417472807   756814787     498,003.92    781857
# 9552          2113824   683154306   527841872     415,482.01    583676
#
#                    Dollars  Classification
# VendorNumber
# 3960         21,315,299.75          102406
# 4425         11,724,670.82          137492
# 12546        10,232,521.65           80509
# 17035        10,224,899.93           50080
# 480           7,420,630.63           41500
# 1392          6,584,032.72          145767
# 1128          5,719,375.62           27159
# 9165          5,545,766.29           56584
# 3252          5,177,067.61          128110
# 9552          4,647,908.17           67928

# %% [markdown]
# ## Deliverable 4b

# %%
invoices = pd.read_csv("InvoicePurchases12-31-16Sample.csv")
invoices.head()
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3           480  BACARDI USA INC              2016-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2016-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2015-12-21  2016-02-16         6     214.26     3.47      NaN
# 1  2015-12-22  2016-02-21        15     140.55     8.57      NaN
# 2  2015-12-24  2016-02-16         5     106.60     4.61      NaN
# 3  2015-12-20  2016-02-05     10100 137,483.78 2,935.20      NaN
# 4  2015-12-24  2016-02-12      1935  15,527.25   429.20      NaN

# %%
freight_grouped = invoices.groupby("VendorNumber").sum("Freight")
freight_grouped.head()
# Out:
#               PONumber  Quantity   Dollars  Freight
# VendorNumber
# 2                40959       328  5,630.88    27.08
# 54               13168         1    105.07     0.48
# 60              415554      4732 76,770.25   367.52
# 105             442896       332 11,706.20    62.39
# 200              71951       132  1,205.16     6.19

# %%
sorted_freight = freight_grouped.sort_values(by="Freight", ascending = False)
sorted_freight.head(10)
# Out:
#               PONumber  Quantity       Dollars    Freight
# VendorNumber
# 3960            597515   5459788 50,959,796.85 257,032.07
# 4425            853524   2640411 27,861,690.02 144,929.24
# 12546           598179   2737165 24,203,151.05 123,880.97
# 17035           597979   1647558 24,124,091.56 123,780.22
# 480             597226   1427075 17,624,378.72  89,286.27
# 1392            597607   2325892 15,573,917.90  79,528.99
# 1128            597191   1006122 13,529,433.08  68,601.68
# 9165            597939   1077527 13,210,613.93  68,054.70
# 3252            597881   1858260 12,289,608.09  61,966.91
# 9552            597511   1372841 10,935,817.30  55,551.82

# %% [markdown]
# ## Deliverable 4c

# %%
invoices_vendors_grouped = invoices[["Quantity", "Dollars", "Freight", "VendorNumber"]].groupby("VendorNumber").sum("Dollars")
invoices_vendors_grouped.head()
# Out:
#               Quantity   Dollars  Freight
# VendorNumber
# 2                  328  5,630.88    27.08
# 54                   1    105.07     0.48
# 60                4732 76,770.25   367.52
# 105                332 11,706.20    62.39
# 200                132  1,205.16     6.19

# %%
over_250 = invoices_vendors_grouped[invoices_vendors_grouped["Dollars"]>=250000]

# %%
over_250.head()
# Out:
#               Quantity       Dollars   Freight
# VendorNumber
# 480            1427075 17,624,378.72 89,286.27
# 516             228103  1,628,866.68  8,510.41
# 653             154092  1,529,682.04  8,014.98
# 660             503931  3,537,977.55 17,932.33
# 1128           1006122 13,529,433.08 68,601.68

# %%
over_250["Freight per Dollar %"] = (over_250["Freight"] / over_250["Dollars"]) * 100
# Out:
# C:\Users\email\AppData\Local\Temp\ipykernel_23372\873694871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   over_250["Freight per Dollar %"] = (over_250["Freight"] / over_250["Dollars"]) * 100

# %%
 over_250.head()
# Out:
#               Quantity       Dollars   Freight  Freight per Dollar %
# VendorNumber
# 480            1427075 17,624,378.72 89,286.27                  0.51
# 516             228103  1,628,866.68  8,510.41                  0.52
# 653             154092  1,529,682.04  8,014.98                  0.52
# 660             503931  3,537,977.55 17,932.33                  0.51
# 1128           1006122 13,529,433.08 68,601.68                  0.51

# %%
sorted_over_250 = over_250.sort_values(by="Freight per Dollar %", ascending=False)

# %%
sorted_over_250.head(10)
# Out:
#               Quantity       Dollars    Freight  Freight per Dollar %
# VendorNumber
# 9625             56860    361,249.21   1,933.19                  0.54
# 1590            187841  1,365,472.83   7,259.75                  0.53
# 9744             70932    759,449.24   3,999.93                  0.53
# 653             154092  1,529,682.04   8,014.98                  0.52
# 17031            20608    300,403.20   1,573.31                  0.52
# 516             228103  1,628,866.68   8,510.41                  0.52
# 4425           2640411 27,861,690.02 144,929.24                  0.52
# 8673            419822  3,086,650.70  15,919.70                  0.52
# 9815            888385  5,258,636.79  27,100.41                  0.52
# 9165           1077527 13,210,613.93  68,054.70                  0.52

# %%
sorted_over_250.tail(5)
# Out:
#               Quantity      Dollars   Freight  Freight per Dollar %
# VendorNumber
# 8352            283260 2,051,436.01 10,261.60                  0.50
# 3924            352348 2,816,661.94 14,069.87                  0.50
# 3089            186464 1,715,908.88  8,549.55                  0.50
# 9819            497770 2,978,686.40 14,836.57                  0.50
# 6359            110162   387,622.69  1,922.00                  0.50

# %% [markdown]
# ## Deliverable 4d

# %%
for_4d = invoices[["Quantity", "Dollars", "Freight", "VendorNumber"]]
for_4d.head()
# Out:
#    Quantity    Dollars  Freight  VendorNumber
# 0         6     214.26     3.47           105
# 1        15     140.55     8.57          4466
# 2         5     106.60     4.61           388
# 3     10100 137,483.78 2,935.20           480
# 4      1935  15,527.25   429.20           516

# %%
meets_4d_req = for_4d[(for_4d["Freight"]>100) & (for_4d["Quantity"]<=1000)]
meets_4d_req.head()
# Out:
#     Quantity  Dollars  Freight  VendorNumber
# 11       320 5,420.41   179.26          1485
# 16       808 6,646.46   127.05          2242
# 19       385 3,506.41   146.86          2555
# 23       136 5,645.24   218.18          2561
# 28       818 7,079.02   200.02          3924

# %%
top_vendors_4d = meets_4d_req.groupby("VendorNumber").sum("Freight").sort_values(by="Freight", ascending = False)

# %%
top_vendors_4d
# Out:
#               Quantity    Dollars  Freight
# VendorNumber
# 2561             18120 570,627.52 2,944.67
# 8664               975  14,299.98   349.02
# 7239               382   7,515.38   348.07
# 653                541   5,544.89   303.70
# 6785               715   5,533.18   242.73
# 10000              875   7,234.88   218.05
# 3924               818   7,079.02   200.02
# 8352               819   6,139.47   196.61
# 4692               427   5,336.48   185.93
# 1485               320   5,420.41   179.26
# 6213               412   4,821.83   177.50
# 9625               795   8,657.44   169.46
# 2555               385   3,506.41   146.86
# 3089               379   4,443.66   133.83
# 2242               808   6,646.46   127.05
# 98450              733  27,163.64   122.24
# 1273               576  20,334.21   109.80
# 4848               982  18,937.82   100.37

# %% [markdown]
# ## Deliverable 4e

# %%
meets_4d_req["Freight per Dollar %"] = (meets_4d_req["Freight"] / meets_4d_req["Dollars"]) * 100
meets_4d_req.head()
# Out:
# C:\Users\email\AppData\Local\Temp\ipykernel_23372\2518527284.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meets_4d_req["Freight per Dollar %"] = (meets_4d_req["Freight"] / meets_4d_req["Dollars"]) * 100
#     Quantity  Dollars  Freight  VendorNumber  Freight per Dollar %
# 11       320 5,420.41   179.26          1485                  3.31
# 16       808 6,646.46   127.05          2242                  1.91
# 19       385 3,506.41   146.86          2555                  4.19
# 23       136 5,645.24   218.18          2561                  3.86
# 28       818 7,079.02   200.02          3924                  2.83

# %%
grouped_4e = meets_4d_req.groupby("VendorNumber").sum("Freight per Dollar %")
grouped_4e
# Out:
#               Quantity    Dollars  Freight  Freight per Dollar %
# VendorNumber
# 653                541   5,544.89   303.70                  5.48
# 1273               576  20,334.21   109.80                  0.54
# 1485               320   5,420.41   179.26                  3.31
# 2242               808   6,646.46   127.05                  1.91
# 2555               385   3,506.41   146.86                  4.19
# 2561             18120 570,627.52 2,944.67                 13.97
# 3089               379   4,443.66   133.83                  3.01
# 3924               818   7,079.02   200.02                  2.83
# 4692               427   5,336.48   185.93                  3.48
# 4848               982  18,937.82   100.37                  0.53
# 6213               412   4,821.83   177.50                  3.68
# 6785               715   5,533.18   242.73                  4.39
# 7239               382   7,515.38   348.07                  4.63
# 8352               819   6,139.47   196.61                  3.20
# 8664               975  14,299.98   349.02                  2.44
# 9625               795   8,657.44   169.46                  1.96
# 10000              875   7,234.88   218.05                  3.01
# 98450              733  27,163.64   122.24                  0.45

# %%
sorted_4e = grouped_4e.sort_values(by="Freight per Dollar %", ascending = False)
sorted_4e
# Out:
#               Quantity    Dollars  Freight  Freight per Dollar %
# VendorNumber
# 2561             18120 570,627.52 2,944.67                 13.97
# 653                541   5,544.89   303.70                  5.48
# 7239               382   7,515.38   348.07                  4.63
# 6785               715   5,533.18   242.73                  4.39
# 2555               385   3,506.41   146.86                  4.19
# 6213               412   4,821.83   177.50                  3.68
# 4692               427   5,336.48   185.93                  3.48
# 1485               320   5,420.41   179.26                  3.31
# 8352               819   6,139.47   196.61                  3.20
# 10000              875   7,234.88   218.05                  3.01
# 3089               379   4,443.66   133.83                  3.01
# 3924               818   7,079.02   200.02                  2.83
# 8664               975  14,299.98   349.02                  2.44
# 9625               795   8,657.44   169.46                  1.96
# 2242               808   6,646.46   127.05                  1.91
# 1273               576  20,334.21   109.80                  0.54
# 4848               982  18,937.82   100.37                  0.53
# 98450              733  27,163.64   122.24                  0.45

# %% [markdown]
# For just transactions where the freight was more than $100 and the quantity was 1,000 units or less the freight per dollar percentage
# is significantly higher than it was in 4c.

# %% [markdown]
# ## Deliverable 5

# %%
sales = pd.read_csv("SalesFINAL12-31-16Sample.csv")
sales.head()
# Out:
#             InventoryId  Store  Brand                   Description  \
# 0   1_HARDERSFIELD_1009      1   1009       Rebel Yell Variety Pack
# 1  1_HARDERSFIELD_10238      1  10238   Layer Cake Primitivo Puglia
# 2  1_HARDERSFIELD_10239      1  10239       Cannonball Cab Svgn Cal
# 3  1_HARDERSFIELD_10266      1  10266  Klinker Brick Old Vine Znfdl
# 4   1_HARDERSFIELD_1029      1   1029  Fulton's Harvest Apple Pie L
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  750mL 3 Pk              1         49.99       49.99  2016-01-02  750.00
# 1       750mL              2         31.98       15.99  2016-01-02  750.00
# 2       750mL              1         13.99       13.99  2016-01-02  750.00
# 3       750mL              1         16.99       16.99  2016-01-09  750.00
# 4       750mL              1          9.99        9.99  2016-01-03  750.00
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       0.79      8352  LUXCO INC
# 1               2       0.22      4425        MARTIGNETTI COMPANIES
# 2               2       0.11      4425        MARTIGNETTI COMPANIES
# 3               2       0.11      9552  M S WALKER INC
# 4               1       0.79      3924  HEAVEN HILL DISTILLERIES

# %%
sales["VendorNumber"] = sales["VendorNo"]
sales.head()
# Out:
#             InventoryId  Store  Brand                   Description  \
# 0   1_HARDERSFIELD_1009      1   1009       Rebel Yell Variety Pack
# 1  1_HARDERSFIELD_10238      1  10238   Layer Cake Primitivo Puglia
# 2  1_HARDERSFIELD_10239      1  10239       Cannonball Cab Svgn Cal
# 3  1_HARDERSFIELD_10266      1  10266  Klinker Brick Old Vine Znfdl
# 4   1_HARDERSFIELD_1029      1   1029  Fulton's Harvest Apple Pie L
#
#          Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0  750mL 3 Pk              1         49.99       49.99  2016-01-02  750.00
# 1       750mL              2         31.98       15.99  2016-01-02  750.00
# 2       750mL              1         13.99       13.99  2016-01-02  750.00
# 3       750mL              1         16.99       16.99  2016-01-09  750.00
# 4       750mL              1          9.99        9.99  2016-01-03  750.00
#
#    Classification  ExciseTax  VendorNo                   VendorName  \
# 0               1       0.79      8352  LUXCO INC
# 1               2       0.22      4425        MARTIGNETTI COMPANIES
# 2               2       0.11      4425        MARTIGNETTI COMPANIES
# 3               2       0.11      9552  M S WALKER INC
# 4               1       0.79      3924  HEAVEN HILL DISTILLERIES
#
#    VendorNumber
# 0          8352
# 1          4425
# 2          4425
# 3          9552
# 4          3924

# %%
purchases.head()
# Out:
#          InventoryId  Store  Brand                   Description   Size  \
# 0  69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1  34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
# 3      5_SUTTON_3348      5   3348           Bombay Sapphire Gin  1.75L
# 4   30_CULCHETH_4903     30   4903          Bacardi Superior Rum  200mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2015-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2015-12-22
# 2           388  ATLANTIC IMPORTING COMPANY       8169  2015-12-24
# 3           480  BACARDI USA INC                  8106  2015-12-20
# 4           480  BACARDI USA INC                  8106  2015-12-20
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# 0    2016-01-02  2016-01-04  2016-02-16          35.71         6   214.26
# 1    2016-01-02  2016-01-07  2016-02-21           9.41         5    47.05
# 2    2016-01-02  2016-01-09  2016-02-16          21.32         5   106.60
# 3    2016-01-02  2016-01-12  2016-02-05          22.38         6   134.28
# 4    2016-01-01  2016-01-12  2016-02-05           2.87        48   137.76
#
#    Classification
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
small_sales = sales[["VendorNumber", "SalesDollars"]].groupby("VendorNumber").sum("SalesDollars")
small_sales.head(10)
# Out:
#               SalesDollars
# VendorNumber
# 2                    86.97
# 60                6,132.40
# 105               1,513.68
# 200                  17.99
# 287                 139.41
# 388               5,090.40
# 480           1,935,245.08
# 516             209,660.93
# 653             178,517.11
# 660             388,267.29

# %%
small_purchases = purchases[["VendorNumber", "Dollars"]].groupby("VendorNumber").sum("Dollars")
small_purchases.head(10)
# Out:
#                   Dollars
# VendorNumber
# 2                1,751.30
# 54                 105.07
# 60              30,175.00
# 105              4,388.99
# 200                764.52
# 287                771.42
# 388             20,321.72
# 480          7,420,630.63
# 516            692,669.85
# 653            650,999.58

# %%
merge5 = pd.merge(left = small_sales, right = small_purchases, how='outer', on=["VendorNumber"])
merge5 = merge5.fillna(0)
merge5.head()
# Out:
#               SalesDollars   Dollars
# VendorNumber
# 2                    86.97  1,751.30
# 60                6,132.40 30,175.00
# 105               1,513.68  4,388.99
# 200                  17.99    764.52
# 287                 139.41    771.42

# %%
merge5["Purchase Amount"] = merge5["Dollars"]

# %%
merge5["Profit"] = merge5["SalesDollars"] - merge5["Purchase Amount"]

# %%
merge5.head()
# Out:
#               SalesDollars   Dollars  Purchase Amount     Profit
# VendorNumber
# 2                    86.97  1,751.30         1,751.30  -1,664.33
# 60                6,132.40 30,175.00        30,175.00 -24,042.60
# 105               1,513.68  4,388.99         4,388.99  -2,875.31
# 200                  17.99    764.52           764.52    -746.53
# 287                 139.41    771.42           771.42    -632.01

# %%
merge5
# Out:
#               SalesDollars   Dollars  Purchase Amount     Profit
# VendorNumber
# 2                    86.97  1,751.30         1,751.30  -1,664.33
# 60                6,132.40 30,175.00        30,175.00 -24,042.60
# 105               1,513.68  4,388.99         4,388.99  -2,875.31
# 200                  17.99    764.52           764.52    -746.53
# 287                 139.41    771.42           771.42    -632.01
# ...                    ...       ...              ...        ...
# 173357            3,045.93 12,455.17        12,455.17  -9,409.24
# 201359              149.94     17.00            17.00     132.94
# 54                    0.00    105.07           105.07    -105.07
# 4901                  0.00    140.94           140.94    -140.94
# 9099                  0.00    236.64           236.64    -236.64
#
# [125 rows x 4 columns]

# %%
sorted_merge5 = merge5[["SalesDollars", "Purchase Amount", "Profit"]].groupby("VendorNumber").sum().sort_values(by="Profit", ascending = False)
sorted_merge5.head(10)
# Out:
#               SalesDollars  Purchase Amount  Profit
# VendorNumber
# 201359              149.94            17.00  132.94
# 90026                27.96             0.00   27.96
# 90033                 7.99             0.00    7.99
# 54                    0.00           105.07 -105.07
# 4901                  0.00           140.94 -140.94
# 9099                  0.00           236.64 -236.64
# 1265                 24.99           365.30 -340.31
# 1003                212.73           701.90 -489.17
# 287                 139.41           771.42 -632.01
# 200                  17.99           764.52 -746.53

# %% [markdown]
# I conducted a profit analysis using the sales data and the purchase data. Above are the top 10 most profitable vendors.
